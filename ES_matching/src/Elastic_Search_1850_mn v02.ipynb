# %% [markdown]
# # install requirements

# %%
# %%capture

# Install txtai and elasticsearch python client
# !pip install git+https://github.com/neuml/txtai elasticsearch

# Download and extract elasticsearch
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.8.1-linux-x86_64.tar.gz
# !tar -xzf elasticsearch-7.8.1-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.8.1

import os
from subprocess import Popen, PIPE, STDOUT

# If issues are encountered with this section, ES can be manually started as follows:
# ./elasticsearch-7.8.1/bin/elasticsearch

# Start and wait for server
server = Popen(['elasticsearch-7.8.1/bin/elasticsearch'], stdout=PIPE, stderr=STDOUT, preexec_fn=lambda: os.setuid(1))
# !sleep 30

# %%
#!wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.3-windows-x86_64.zip

#!unzip elasticsearch-7.9.3-windows-x86_64.zip
#!chown -R daemon:daemon elasticsearch-7.9.3
# start server
#import os
#from subprocess import Popen, PIPE, STDOUT
#es_server = Popen(['elasticsearch-7.9.3/bin/elasticsearch'], 
#                  stdout=PIPE, stderr=STDOUT,
#                  preexec_fn=lambda: os.setuid(1)  # as daemon
#                 )
# wait a bit then test
#!curl -X GET "http://localhost:8888"

# %% [markdown]
# install requirements

# %%
# install requirements
# !pip install elasticsearch
# !pip install metaphone
# !pip install pyjarowinkler
# !pip install python-Levenshtein
# !pip install python-dateutil
# Out:
# Requirement already satisfied: elasticsearch in /usr/local/lib/python3.6/dist-packages (7.10.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from elasticsearch) (2020.11.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from elasticsearch) (1.24.3)
# Collecting metaphone
#   Downloading https://files.pythonhosted.org/packages/d4/ae/c9e4d007e32a6469be212da11d0b8e104d643f6f247d771742caf6ac6bb8/Metaphone-0.6.tar.gz
# Building wheels for collected packages: metaphone
#   Building wheel for metaphone (setup.py) ... done
#   Created wheel for metaphone: filename=Metaphone-0.6-cp36-none-any.whl size=13907 sha256=38b60d60cb9c2735c62866d8a7d2d411d8ec10c0594c85b56d796b7fe8897a1c
#   Stored in directory: /root/.cache/pip/wheels/4e/7c/f7/162d726fc83491ef23c7a0b989005024eb83a1408c96f32eaf
# Successfully built metaphone
# Installing collected packages: metaphone
# Successfully installed metaphone-0.6
# Collecting pyjarowinkler
#   Downloading https://files.pythonhosted.org/packages/b9/58/b89073047b447e02b08d4f64fbb984e5a4dfef4134477350b256c625c779/pyjarowinkler-1.8-py2.py3-none-any.whl
# Installing collected packages: pyjarowinkler
# Successfully installed pyjarowinkler-1.8
# Collecting python-Levenshtein
#   Downloading https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 2.8MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-Levenshtein) (50.3.2)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp36-cp36m-linux_x86_64.whl size=144794 sha256=112130f88a09fe6fa3de1eec28793ac347a157c016c7301bc5a131a02fc0ce31
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.0
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil) (1.15.0)

# %% [markdown]
# ### import lib for data ingestion

# %%
# import lib for data ingestion
from elasticsearch import Elasticsearch
from argparse import ArgumentParser
import csv,time,logging, json
import pandas as pd
import numpy as np
from elasticsearch import helpers
from metaphone import doublemetaphone
from elasticsearch import exceptions

# %%
server = Popen(['elasticsearch-7.8.1/bin/elasticsearch'], stdout=PIPE, stderr=STDOUT, preexec_fn=lambda: os.setuid(1))
# !sleep 30

# %% [markdown]
# ### Replicate the work done by previous RAs

# %% [markdown]
# ##### data ingestion

# %%
es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename="/content/bulk_insert.log",
                            filemode='a',
                            format='%(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('InsertTime')

def ingest(config):
    df = pd.read_csv(config['census_filename'])
    bulk_data = []
    count = 0 
    for itr, row in df.iterrows():
        count+=1
        row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
        data = row.to_dict() #converts the dataframe row to dictonary with their correct data type
        if 'LOCATION' in data:
          data['LOCATION'] = {"lat":data["LAT"],"lon":data["LONG"]} # find location
        
        if 'ADDNUMFROM' in data and type(data['ADDNUMFROM']) is str:
            data['ADDNUMFROM'] = data['ADDNUMFROM'].replace('`','')

        data[config['census_first_name']] = name_clean(data[config['census_first_name']])
        data[config['census_last_name']] = name_clean(data[config['census_last_name']])
        
        if config['metaphone'] is 1: # default metaphone is 1
          data['METAPHONE_NAMEFIRST'] = [i for i in doublemetaphone(data[config['census_first_name']]) if i]
          data['METAPHONE_NAMELAST'] = [i for i in doublemetaphone(data[config['census_last_name']]) if i]
        
        if id is not False:
          meta = {
              "_index": config['es-index'],
              "_id": data[config['es-id']],
              "_source": data
          }
        else:
          meta = {
              "_index": config['es-index'],
              "_source": data
          }

        bulk_data.append(meta)
        if itr%config['ingest_size'] == 0:
            helpers.bulk(es, bulk_data)
            bulk_data = []
            print("INSERTING NOW", itr)
            
    helpers.bulk(es, bulk_data)
    return count

def name_clean(name):
  return max(name.split(' '), key=len)

if __name__=='__main__':
    if __name__ == '__main__':
      #parser = ArgumentParser()
      #parser.add_argument("-config", help="config file path", default="/content/config_1850.json")

      #args = parser.parse_args()

      #with open(args.config) as json_data_file:
      #  config = json.load(json_data_file)
      with open('/content/config_1880.json') as json_data_file:
         config = json.load(json_data_file)


      st = time.time()
      ingest(config)
      end = time.time()
      logger.warning(config["es-index"] +" "+ str(end-st))
 
#Mapping used
'''
PUT census
{
    "mappings" : {
      "properties" : {
        "ADDNUM" : {
          "type" : "long"
        },
        "ADDNUMFROM" : {
          "type" : "long"
        },
        "ADDNUMTO" : {
          "type" : "long"
        },
        "ADDR_TYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ADDRESSB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_AGEB" : {
          "type" : "long"
        },
        "CENSUS_BUILDING_I" : {
          "type" : "long"
        },
        "CENSUS_CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ED" : {
          "type" : "long"
        },
        "CENSUS_ENUMDISTB" : {
          "type" : "long"
        },
        "CENSUS_EXTGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_FID" : {
          "type" : "long"
        },
        "CENSUS_MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_MERGEID" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMEFRSTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMELASTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NEIGHBOR_1" : {
          "type" : "long"
        },
        "CENSUS_NEIGHBOR_2" : {
          "type" : "long"
        },
        "CENSUS_NPERHHB" : {
          "type" : "long"
        },
        "CENSUS_OCCLABELB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_PAGENUMB" : {
          "type" : "long"
        },
        "CENSUS_RACEB" : {
          "type" : "long"
        },
        "CENSUS_RACENAMEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_REELB" : {
          "type" : "long"
        },
        "CENSUS_RELATEB" : {
          "type" : "long"
        },
        "CENSUS_RELATE_STR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_SEGGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_SEGMENT_ID" : {
          "type" : "long"
        },
        "CENSUS_SERIAL" : {
          "type" : "long"
        },
        "CENSUS_SERIALB" : {
          "type" : "long"
        },
        "CENSUS_SEXB" : {
          "type" : "long"
        },
        "CENSUS_STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREET" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREETB" : {
          "type" : "long"
        },
        "CENSUS_TYPEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_UNITTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_VOLUMEB" : {
          "type" : "long"
        },
        "CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "COUNTY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "LOCATION":{
             "type": "geo_point"
        },
        "LAT" : {
          "type" : "float"
        },
        "LONG" : {
          "type" : "float"
        },
        "MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "METAPHONE_NAMEFIRST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "METAPHONE_NAMELAST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "OBJECTID" : {
          "type" : "long"
        },
        "SIDE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STNAME" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPREDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPRETYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WARD_NUM" : {
          "type" : "long"
        }
      }
    }
  }
'''

# %% [markdown]
# ##### matching
#
# edit dist 0: match only on ward no and metaphone - 125k cd records matched to 873k census records
#
# 63k cd records remain unmatched

# %%
# edit dist 0: match only on ward no and metaphone
with open('/content/config_1880.json') as json_data_file:
    config = json.load(json_data_file)


es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

config['match_output_filename'] = "/content/test_1880mn_old.csv"
config['unmatch_output_filename'] = "/content/test-u_1880mn_old.csv"

logging.basicConfig(filename='/content/direct_match.log',
                            filemode='a',
                            format='%(created)f %(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('directMatch')

def get_matches():
    df = pd.read_csv(config['cd_filename'])
    count_match, count_unmatch=0,0

    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t")
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""

        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        
        for idx, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
        
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0: # edit distance is used to find matches
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    { "match" : { "CENSUS_ED": data["CD_ED"]} },
                                    {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                                    {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]
                            }}

                else:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    { "match" : { "CENSUS_ED": data["CD_ED"]}}
                                    ],
                            }}
            

            if config['edit_distance'] is 0:
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [ { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            #{ "match" : { "CENSUS_ED": data["CD_ED"]} }, #add this back in once ed column data is fixed
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}
                            ]}}
            
                else:
                    query = { "bool" : { "must" : [{ "match": { "CENSUS_FIRST_NAME": data["CD_FIRST_NAME"] } },
                            { "match": { "CENSUS_LAST_NAME": data["CD_LAST_NAME"] } },
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            { "match" : { "CENSUS_ED": data["CD_ED"]} }
                            ]}}

            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError as e:
                print(idx)
                continue
        
            if res['hits']['total']['value']!= 0:
                count_match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))

            else:
                fw2.write(str(data['CD_RECORD_ID'])+"\n")
                count_unmatch+=1


    logging.warning("Total city directory matched: "+ str(count_match))
    logging.warning("Total city directory unmatched: "+ str(count_unmatch))

    print(count_match,count_unmatch)

def name_clean(name):
  return max(name.split(' '), key=len)

def export_data(data):
    json.dump(data, open('/content/matched_data.json','w'))

if __name__=='__main__':
    get_matches()
# Out:
# 125819 63476

# %% [markdown]
# ### change diff conditions to see if matches improve

# %% [markdown]
# ##### edit distance 0, match on ward no, metaphone, first name and last name - 8k cd records matched

# %%
# edit distance 0, match on ward no, metaphone, first name and last name
with open('/content/config_1880.json') as json_data_file:
    config = json.load(json_data_file)


es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename='/content/direct_match.log',
                            filemode='a',
                            format='%(created)f %(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('directMatch')

def get_matches():
    df = pd.read_csv(config['cd_filename'])
    count_match, count_unmatch=0,0

    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t")
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""

        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        
        for idx, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
        
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]


            if config['edit_distance'] is 0:
                if config['metaphone'] is 1:
                   
                    query =  { "bool" : { "must" : [{ "match": { "CENSUS_FIRST_NAME": data["CD_FIRST_NAME"] } },
                            { "match": { "CENSUS_LAST_NAME": data["CD_LAST_NAME"] } },
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}
                    """
                    query = { "bool" : { "must" : [ { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            { "match" : { "CENSUS_ED": data["CD_ED"]} }, #add this back in once ed column data is fixed
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}
                            ]}}
                    """      
            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError as e:
                print(idx)
                continue
        
            if res['hits']['total']['value']!= 0:
                count_match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))

            else:
                fw2.write(str(data['CD_RECORD_ID'])+"\n")
                count_unmatch+=1


    logging.warning("Total city directory matched: "+ str(count_match))
    logging.warning("Total city directory unmatched: "+ str(count_unmatch))

    print(count_match,count_unmatch)

def name_clean(name):
  return max(name.split(' '), key=len)

def export_data(data):
    json.dump(data, open('/content/matched_data.json','w'))

if __name__=='__main__':
    get_matches()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (3,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# 8975 180320

# %% [markdown]
# ##### match only on metaphone - 36k cd records match

# %%
# match only on metaphone
with open('/content/config_1880.json') as json_data_file:
    config = json.load(json_data_file)


es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename='/content/direct_match.log',
                            filemode='a',
                            format='%(created)f %(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('directMatch')

config['edit_distance'] = 2

def get_matches():
    df = pd.read_csv(config['cd_filename'])
    count_match, count_unmatch=0,0

    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t")
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""

        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        
        for idx, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
        
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0: # edit distance is used to find matches
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [
                                    {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                                    {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]
                            }}

            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError as e:
                print(idx)
                continue
        
            if res['hits']['total']['value']!= 0:
                count_match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))

            else:
                fw2.write(str(data['CD_RECORD_ID'])+"\n")
                count_unmatch+=1


    logging.warning("Total city directory matched: "+ str(count_match))
    logging.warning("Total city directory unmatched: "+ str(count_unmatch))

    print(count_match,count_unmatch)

def name_clean(name):
  return max(name.split(' '), key=len)

def export_data(data):
    json.dump(data, open('/content/matched_data.json','w'))

if __name__=='__main__':
    get_matches()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (3,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# 36922 152373

# %% [markdown]
# ##### edit distance 2, match on ward no, metaphone, first name and last name - 105k cd records matched to 354k census records and 83k cd records non match

# %%
# edit distance 2, match on ward no, metaphone, first name and last name
with open('/content/config_1880.json') as json_data_file:
    config = json.load(json_data_file)


es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename='/content/direct_match.log',
                            filemode='a',
                            format='%(created)f %(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('directMatch')

config['edit_distance'] = 2

def get_matches():
    df = pd.read_csv(config['cd_filename'])
    count_match, count_unmatch=0,0

    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t")
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""

        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        
        for idx, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
        
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0: # edit distance is used to find matches
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    #{ "match" : { "CENSUS_ED": data["CD_ED"]} },
                                    {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                                    {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]
                            }}


            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError as e:
                print(idx)
                continue
        
            if res['hits']['total']['value']!= 0:
                count_match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))

            else:
                fw2.write(str(data['CD_RECORD_ID'])+"\n")
                count_unmatch+=1


    logging.warning("Total city directory matched: "+ str(count_match))
    logging.warning("Total city directory unmatched: "+ str(count_unmatch))

    print(count_match,count_unmatch)

def name_clean(name):
  return max(name.split(' '), key=len)

def export_data(data):
    json.dump(data, open('/content/matched_data.json','w'))

if __name__=='__main__':
    get_matches()
# Out:
# 105530 83765

# %% [markdown]
# ##### edit distance 2, match on ward no, ed, metaphone, first name and last name - 79k cd records matched with 102k census data and 104k unmatched

# %%
# edit distance 2, match on ward no, metaphone, ed, first name and last name
with open('/content/config_1880.json') as json_data_file:
    config = json.load(json_data_file)


es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename='/content/direct_match.log',
                            filemode='a',
                            format='%(created)f %(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('directMatch')

config['edit_distance'] = 2

def get_matches():
    df = pd.read_csv(config['cd_filename'])
    count_match, count_unmatch=0,0

    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t")
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""

        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        
        for idx, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
        
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0: # edit distance is used to find matches
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    { "match" : { "CENSUS_ED": data["CD_ED"]} },
                                    {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                                    {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]
                            }}


            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError as e:
                print(idx)
                continue
        
            if res['hits']['total']['value']!= 0:
                count_match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))

            else:
                fw2.write(str(data['CD_RECORD_ID'])+"\n")
                count_unmatch+=1


    logging.warning("Total city directory matched: "+ str(count_match))
    logging.warning("Total city directory unmatched: "+ str(count_unmatch))

    print(count_match,count_unmatch)

def name_clean(name):
  return max(name.split(' '), key=len)

def export_data(data):
    json.dump(data, open('/content/matched_data.json','w'))

if __name__=='__main__':
    get_matches()
# Out:
# 135676
# 135759
# 135765
# 135767
# 135936
# 135937
# 135961
# 135974
# 135995
# 136000
# 136006
# 136012
# 136020
# 136031
# 136044
# 136068
# 136087
# 136136
# 136197
= Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename='/content/direct_match.log',
                            filemode='a',
                            format='%(created)f %(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('directMatch')
#config['edit_distance'] = 0

def get_matches():
    df = pd.read_csv(config['cd_filename'])
    count_match, count_unmatch=0,0

    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t")
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""

        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        
        for idx, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
        
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]



            if config['edit_distance'] !=0: # edit distance is used to find matches
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    { "match" : { "CENSUS_ED": data["CD_ED"]} },
                                    {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                                    {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]
                            }}

                else:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    { "match" : { "CENSUS_ED": data["CD_ED"]}}
                                    ],
                            }}
            

            if config['edit_distance'] is 0:
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [ { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            { "match" : { "CENSUS_ED": data["CD_ED"]} }, #add this back in once ed column data is fixed
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}
                            ]}}
            
                else:
                    query = { "bool" : { "must" : [{ "match": { "CENSUS_FIRST_NAME": data["CD_FIRST_NAME"] } },
                            { "match": { "CENSUS_LAST_NAME": data["CD_LAST_NAME"] } },
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            { "match" : { "CENSUS_ED": data["CD_ED"]} }
                            ]}}

            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError as e:
                print(idx)
                continue
        
            if res['hits']['total']['value']!= 0:
                count_match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))

            else:
# 184370
# 184466
# 184530
# 184532
# 184533
# 184539
# 184554
# 184591
# 184611
# 184633
# 184648
# 184652
# 184687
# 184697
# 184770
# 184784
# 184801
# 184826
# 184882
# 184894
# 185010
# 185078
# 185083
# 185103
# 185135
# 185147
# 185180
# 185199
# 185327
# 185332
# 185384
# 185481
# 185512
# 185535
# 185567
# 185622
# 185623
# 185636
# 185650
# 185676
# 185683
# 185687
# 185812
# 185917
# 185955
# 186025
# 186047
# 186056
# 186068
# 186079
# 186132
# 186138
# 186220
# 186362
# 186388
# 186392
# 186476
# 186484
# 186511
# 186629
# 186637
# 186654
# 186723
# 186748
# 186861
# 186873
# 186930
# 186999
# 187005
# 187057
# 187080
# 187104
# 187136
# 187160
# 187183
# 187200
# 187220
# 187250
# 187269
# 187347
# 187433
# 187452
# 187498
# 187502
# 187538
# 187559
# 187614
# 187672
# 187673
# 187693
# 187714
# 187876
# 187902
# 187908
# 187927
# 187935
# 187945
# 187986
# 188023
# 188071
# 188105
# 188125
# 188190
# 188262
# 188426
# 188432
# 188450
# 188471
# 188493
# 188503
# 188512
# 188520
# 188543
# 188604
# 188633
# 188674
# 188689
# 188817
# 188877
# 188894
# 188941
# 188975
# 188997
# 189010
# 189036
# 189071
# 189126
# 189147
# 189161
# 189167
# 189203
# 189268
# 91637 92400

# %% [markdown]
# ### changes to  1880 data ingestion and match process
# 1. name cleaning - remove few identfied special characters. can be more which went unrecognized
#
# 2. durng matching used multiple criteria:
#         first match on all conditions: first name, last name, ward no, ed and metaphones
#
#         for remaining unmatched records match with ward no, ed and metaphones only and remove match condition for first name and last name

# %% [markdown]
# #### data ingestion

# %%
import re
es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename="/content/bulk_insert.log",
                            filemode='a',
                            format='%(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('InsertTime')

def ingest(config):
    df = pd.read_csv(config['census_filename'])
    bulk_data = []
    count = 0 
    for itr, row in df.iterrows():
        count+=1
        row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
        data = row.to_dict() #converts the dataframe row to dictonary with their correct data type
        if 'LOCATION' in data:
          data['LOCATION'] = {"lat":data["LAT"],"lon":data["LONG"]} # find location
        
        if 'ADDNUMFROM' in data and type(data['ADDNUMFROM']) is str:
            data['ADDNUMFROM'] = data['ADDNUMFROM'].replace('`','')

        data[config['census_first_name']] = name_clean(data[config['census_first_name']])
        data[config['census_last_name']] = name_clean(data[config['census_last_name']])
        
        if config['metaphone'] is 1: # default metaphone is 1
          data['METAPHONE_NAMEFIRST'] = [i for i in doublemetaphone(data[config['census_first_name']]) if i]
          data['METAPHONE_NAMELAST'] = [i for i in doublemetaphone(data[config['census_last_name']]) if i]
        
        if id is not False:
          meta = {
              "_index": config['es-index'],
              "_id": data[config['es-id']],
              "_source": data
          }
        else:
          meta = {
              "_index": config['es-index'],
              "_source": data
          }

        bulk_data.append(meta)
        if itr%config['ingest_size'] == 0:
            helpers.bulk(es, bulk_data)
            bulk_data = []
            print("INSERTING NOW", itr)
            
    helpers.bulk(es, bulk_data)
    return count

def name_clean(name):
  name = max(name.split(' '), key=len) # remove middle name if any
  name = re.sub('[^A-Za-z0-9]+', '', name)
   
  return name

if __name__=='__main__':
    if __name__ == '__main__':
      #parser = ArgumentParser()
      #parser.add_argument("-config", help="config file path", default="/content/config_1850.json")

      #args = parser.parse_args()

      #with open(args.config) as json_data_file:
      #  config = json.load(json_data_file)
      with open('/content/config_1880.json') as json_data_file:
         config = json.load(json_data_file)


      st = time.time()
      ingest(config)
      end = time.time()
      logger.warning(config["es-index"] +" "+ str(end-st))
 
#Mapping used
'''
PUT census
{
    "mappings" : {
      "properties" : {
        "ADDNUM" : {
          "type" : "long"
        },
        "ADDNUMFROM" : {
          "type" : "long"
        },
        "ADDNUMTO" : {
          "type" : "long"
        },
        "ADDR_TYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ADDRESSB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_AGEB" : {
          "type" : "long"
        },
        "CENSUS_BUILDING_I" : {
          "type" : "long"
        },
        "CENSUS_CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ED" : {
          "type" : "long"
        },
        "CENSUS_ENUMDISTB" : {
          "type" : "long"
        },
        "CENSUS_EXTGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_FID" : {
          "type" : "long"
        },
        "CENSUS_MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_MERGEID" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMEFRSTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMELASTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NEIGHBOR_1" : {
          "type" : "long"
        },
        "CENSUS_NEIGHBOR_2" : {
          "type" : "long"
        },
        "CENSUS_NPERHHB" : {
          "type" : "long"
        },
        "CENSUS_OCCLABELB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_PAGENUMB" : {
          "type" : "long"
        },
        "CENSUS_RACEB" : {
          "type" : "long"
        },
        "CENSUS_RACENAMEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_REELB" : {
          "type" : "long"
        },
        "CENSUS_RELATEB" : {
          "type" : "long"
        },
        "CENSUS_RELATE_STR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_SEGGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_SEGMENT_ID" : {
          "type" : "long"
        },
        "CENSUS_SERIAL" : {
          "type" : "long"
        },
        "CENSUS_SERIALB" : {
          "type" : "long"
        },
        "CENSUS_SEXB" : {
          "type" : "long"
        },
        "CENSUS_STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREET" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREETB" : {
          "type" : "long"
        },
        "CENSUS_TYPEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_UNITTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_VOLUMEB" : {
          "type" : "long"
        },
        "CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "COUNTY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "LOCATION":{
             "type": "geo_point"
        },
        "LAT" : {
          "type" : "float"
        },
        "LONG" : {
          "type" : "float"
        },
        "MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "METAPHONE_NAMEFIRST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "METAPHONE_NAMELAST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "OBJECTID" : {
          "type" : "long"
        },
        "SIDE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STNAME" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPREDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPRETYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WARD_NUM" : {
          "type" : "long"
        }
      }
    }
  }
'''
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# INSERTING NOW 0
# INSERTING NOW 10000
# INSERTING NOW 20000
# INSERTING NOW 30000
# INSERTING NOW 40000
# INSERTING NOW 50000
# INSERTING NOW 60000
# INSERTING NOW 70000
# INSERTING NOW 80000
# INSERTING NOW 90000
# INSERTING NOW 100000
# INSERTING NOW 110000
# INSERTING NOW 120000
# INSERTING NOW 130000
# INSERTING NOW 140000
# INSERTING NOW 150000
# INSERTING NOW 160000
# INSERTING NOW 170000
# INSERTING NOW 180000
# INSERTING NOW 190000
# INSERTING NOW 200000
# INSERTING NOW 210000
# INSERTING NOW 220000
# INSERTING NOW 230000
# INSERTING NOW 240000
# INSERTING NOW 250000
# INSERTING NOW 260000
# INSERTING NOW 270000
# INSERTING NOW 280000
# INSERTING NOW 290000
# INSERTING NOW 300000
# INSERTING NOW 310000
# INSERTING NOW 320000
# INSERTING NOW 330000
# INSERTING NOW 340000
# INSERTING NOW 350000
# INSERTING NOW 360000
# INSERTING NOW 370000
# INSERTING NOW 380000
# INSERTING NOW 390000
# INSERTING NOW 400000
# INSERTING NOW 410000
# INSERTING NOW 420000
# INSERTING NOW 430000
# INSERTING NOW 440000
# INSERTING NOW 450000
# INSERTING NOW 460000
# INSERTING NOW 470000
# INSERTING NOW 480000
# INSERTING NOW 490000
# INSERTING NOW 500000
# INSERTING NOW 510000
# INSERTING NOW 520000
# INSERTING NOW 530000
# INSERTING NOW 540000
# INSERTING NOW 550000
# INSERTING NOW 560000
# INSERTING NOW 570000
# INSERTING NOW 580000
# INSERTING NOW 590000
# INSERTING NOW 600000
# INSERTING NOW 610000
# INSERTING NOW 620000
# INSERTING NOW 630000
# INSERTING NOW 640000
# INSERTING NOW 650000
# INSERTING NOW 660000
# INSERTING NOW 670000
# INSERTING NOW 680000
# INSERTING NOW 690000
# INSERTING NOW 700000
# INSERTING NOW 710000
# INSERTING NOW 720000
# INSERTING NOW 730000
# INSERTING NOW 740000
# INSERTING NOW 750000
# INSERTING NOW 760000
# INSERTING NOW 770000
# INSERTING NOW 780000
# INSERTING NOW 790000
# INSERTING NOW 800000
# INSERTING NOW 810000
# INSERTING NOW 820000
# INSERTING NOW 830000
# INSERTING NOW 840000
# INSERTING NOW 850000
# INSERTING NOW 860000
# INSERTING NOW 870000
# INSERTING NOW 880000
# INSERTING NOW 890000
# INSERTING NOW 900000
# INSERTING NOW 910000
# INSERTING NOW 920000
# INSERTING NOW 930000
# INSERTING NOW 940000
# INSERTING NOW 950000
# INSERTING NOW 960000
# INSERTING NOW 970000
# INSERTING NOW 980000
# INSERTING NOW 990000
# INSERTING NOW 1000000
# INSERTING NOW 1010000
# INSERTING NOW 1020000
# INSERTING NOW 1030000
# INSERTING NOW 1040000
# INSERTING NOW 1050000
# INSERTING NOW 1060000
# INSERTING NOW 1070000
# INSERTING NOW 1080000
# INSERTING NOW 1090000
# INSERTING NOW 1100000
# INSERTING NOW 1110000
# '\nPUT census\n{\n    "mappings" : {\n      "properties" : {\n        "ADDNUM" : {\n          "type" : "long"\n        },\n        "ADDNUMFROM" : {\n          "type" : "long"\n        },\n        "ADDNUMTO" : {\n          "type" : "long"\n        },\n        "ADDR_TYPE" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_ADDRESSB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_AGEB" : {\n          "type" : "long"\n        },\n        "CENSUS_BUILDING_I" : {\n          "type" : "long"\n        },\n        "CENSUS_CITY" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_ED" : {\n          "type" : "long"\n        },\n        "CENSUS_ENUMDISTB" : {\n          "type" : "long"\n        },\n        "CENSUS_EXTGROUP_I" : {\n          "type" : "long"\n        },\n        "CENSUS_FID" : {\n          "type" : "long"\n        },\n        "CENSUS_MATCH_ADDR" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_MERGEID" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_NAMEFRSTB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_NAMELASTB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_NEIGHBOR_1" : {\n          "type" : "long"\n        },\n        "CENSUS_NEIGHBOR_2" : {\n          "type" : "long"\n        },\n        "CENSUS_NPERHHB" : {\n          "type" : "long"\n        },\n        "CENSUS_OCCLABELB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_PAGENUMB" : {\n          "type" : "long"\n        },\n        "CENSUS_RACEB" : {\n          "type" : "long"\n        },\n        "CENSUS_RACENAMEB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_REELB" : {\n          "type" : "long"\n        },\n        "CENSUS_RELATEB" : {\n          "type" : "long"\n        },\n        "CENSUS_RELATE_STR" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_SEGGROUP_I" : {\n          "type" : "long"\n        },\n        "CENSUS_SEGMENT_ID" : {\n          "type" : "long"\n        },\n        "CENSUS_SERIAL" : {\n          "type" : "long"\n        },\n        "CENSUS_SERIALB" : {\n          "type" : "long"\n        },\n        "CENSUS_SEXB" : {\n          "type" : "long"\n        },\n        "CENSUS_STATE" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_STREET" : {\n          "type" : "text",\n          "fields" : {\n ...

# %% [markdown]
# #### matching

# %%
with open('/content/config_1880.json') as json_data_file:
    config = json.load(json_data_file)

es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

config['match_output1_filename'] = "/content/test_match_allcond.csv"
config['match_output2_filename'] = "/content/test_match_noward.csv"
config['match_output3_filename'] = "/content/test_match_nonamematch.csv"
config['match_output4_filename'] = "/content/test_match_onlymetaphone.csv"
config['identifier_col'] = ['identifier_col']

def match_addr():
    df = pd.read_csv(config['cd_filename'])
    count, match,unmatch = 0,0,0
    with open(config['match_output_filename'],'w') as fw, open(config['match_output1_filename'],'w') as fw1, open(config['match_output2_filename'],'w') as fw2, open(config['match_output3_filename'],'w') as fw3, open(config['match_output4_filename'],'w') as fw4, open(config['unmatch_output_filename'],'w') as fw5:
        writer = csv.writer(fw, delimiter="\t",quotechar='"')
        columns = config['identifier_col'] + config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""
        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))


        for index, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
            
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0:
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                                    { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                                    { "match" : { "CENSUS_ED": data["CD_ED"]} },
                                    {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                                    {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]
                            }}

                    query3 = { "bool" : { "must" : [ { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            { "match" : { "CENSUS_ED": data["CD_ED"]} }, #add this back in once ed column data is fixed
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}
                            ]}}
                else:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} }]}}
            
            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
                res3 = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query3})
                #res2 = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query2})
                #res4 = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query4})
                

            except exceptions.RequestError:
                print("Exception at row id: ", index)
                continue
            
            if res['hits']['total']['value']!= 0:
                match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["identifier_col"]:
                        content = content + 'allconditions' + "\t"
                    
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
                    fw1.write(str(data['CD_RECORD_ID'])+"\n")

            
            elif res3['hits']['total']['value']!= 0:
                match+=1
                for i in res3['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["identifier_col"]:
                        content = content + 'nonamematch' + "\t"

                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
                    fw3.write(str(data['CD_RECORD_ID'])+"\n")

            else:
                fw5.write(str(data['CD_RECORD_ID'])+"\n")
                unmatch+=1
        
    print(count,match,unmatch)

def name_clean(name):
  name = max(name.split(' '), key=len) # remove middle name if any
  name = re.sub('[^A-Za-z0-9]+', '', name)
   
  return name
  

if __name__=='__main__':
    match_addr()
# Out:
# Streaming output truncated to the last 5000 lines.
# Exception at row id:  9379
# Exception at row id:  9394
# Exception at row id:  9424
# Exception at row id:  9426
# Exception at row id:  9465
# Exception at row id:  9490
# Exception at row id:  9492
# Exception at row id:  9513
# Exception at row id:  9516
# Exception at row id:  9520
# Exception at row id:  9531
# Exception at row id:  9536
# Exception at row id:  9546
# Exception at row id:  9568
# Exception at row id:  9611
# Exception at row id:  9612
# Exception at row id:  9721
# Exception at row id:  9758
# Exception at row id:  9811
# Exception at row id:  9882
# Exception at row id:  9889
# Exception at row id:  9922
# Exception at row id:  9991
# Exception at row id:  10113
# Exception at row id:  10129
# Exception at row id:  10152
# Exception at row id:  10173
# Exception at row id:  10183
# Exception at row id:  10192
# Exception at row id:  10248
# Exception at row id:  10279
# Exception at row id:  10280
# Exception at row id:  10289
# Exception at row id:  10336
# Exception at row id:  10350
# Exception at row id:  10353
# Exception at row id:  10497
# Exception at row id:  10513
# Exception at row id:  10558
# Exception at row id:  10563
# Exception at row id:  10624
# Exception at row id:  10633
# Exception at row id:  10683
# Exception at row id:  10739
# Exception at row id:  10759
# Exception at row id:  10760
# Exception at row id:  10781
# Exception at row id:  10827
# Exception at row id:  10890
# Exception at row id:  10907
# Exception at row id:  10931
# Exception at row id:  10946
# Exception at row id:  11005
# Exception at row id:  11039
# Exception at row id:  11136
# Exception at row id:  11138
# Exception at row id:  11166
# Exception at row id:  11180
# Exception at row id:  11246
# Exception at row id:  11291
# Exception at row id:  11307
# Exception at row id:  11342
# Exception at row id:  11356
# Exception at row id:  11359
# Exception at row id:  11360
# Exception at row id:  11400
# Exception at row id:  11406
# Exception at row id:  11408
# Exception at row id:  11410
# Exception at row id:  11555
# Exception at row id:  11672
# Exception at row id:  11709
# Exception at row id:  11729
# Exception at row id:  11744
# Exception at row id:  11762
# Exception at row id:  11764
# Exception at row id:  11845
# Exception at row id:  11859
# Exception at row id:  11887
# Exception at row id:  11943
# Exception at row id:  11948
# Exception at row id:  11949
# Exception at row id:  11969
# Exception at row id:  12021
# Exception at row id:  12041
# Exception at row id:  12052
# Exception at row id:  12061
# Exception at row id:  12097
# Exception at row id:  12148
# Exception at row id:  12186
# Exception at row id:  12331
# Exception at row id:  12475
# Exception at row id:  12496
# Exception at row id:  12520
# Exception at row id:  12596
# Exception at row id:  12600
# Exception at row id:  12630
# Exception at row id:  12648
# Exception at row id:  12670
# Exception at row id:  12713
# Exception at row id:  12725
# Exception at row id:  12772
# Exception at row id:  12783
# Exception at row id:  12790
# Exception at row id:  12839
# Exception at row id:  12840
# Exception at row id:  13081
# Exception at row id:  13134
# Exception at row id:  13142
# Exception at row id:  13145
# Exception at row id:  13229
# Exception at row id:  13346
# Exception at row id:  13363
# Exception at row id:  13396
# Exception at row id:  13430
# Exception at row id:  13462
# Exception at row id:  13532
# Exception at row id:  13535
# Exception at row id:  13558
# Exception at row id:  13566
# Exception at row id:  13592
# Exception at row id:  13625
# Exception at row id:  13664
# Exception at row id:  13718
# Exception at row id:  13752
# Exception at row id:  13773
# Exception at row id:  13774
# Exception at row id:  13791
# Exception at row id:  13920
# Exception at row id:  14001
# Exception at row id:  14023
# Exception at row id:  14094
# Exception at row id:  14121
# Exception at row id:  14170
# Exception at row id:  14203
# Exception at row id:  14256
# Exception at row id:  14279
# Exception at row id:  14294
# Exception at row id:  14333
# Exception at row id:  14337
# Exception at row id:  14341
# Exception at row id:  14344
# Exception at row id:  14415
# Exception at row id:  14471
# Exception at row id:  14561
# Exception at row id:  14598
# Exception at row id:  14794
# Exception at row id:  14823
# Exception at row id:  14835
# Exception at row id:  15058
# Exception at row id:  15086
# Exception at row id:  15129
# Exception at row id:  15155
# Exception at row id:  15173
# Exception at row id:  15174
# Exception at row id:  15192
# Exception at row id:  15212
# Exception at row id:  15245
# Exception at row id:  15307
# Exception at row id:  15309
# Exception at row id:  15326
# Exception at row id:  15385
# Exception at row id:  15426
# Exception at row id:  15615
# Exception at row id:  15623
# Exception at row id:  15624
# Exception at row id:  15642
# Exception at row id:  15679
# Exception at row id:  15756
# Exception at row id:  15776
# Exception at row id:  15786
# Exception at row id:  15845
# Exception at row id:  15872
# Exception at row id:  15888
# Exception at row id:  15905
# Exception at row id:  15923
# Exception at row id:  15937
# Exception at row id:  15980
# Exception at row id:  16003
# Exception at row id:  16004
# Exception at row id:  16008
# Exception at row id:  16044
# Exception at row id:  16046
# Exception at row id:  16081
# Exception at row id:  16085
# Exception at row id:  16261
# Exception at row id:  16369
# Exception at row id:  16407
# Exception at row id:  16445
# Exception at row id:  16469
# Exception at row id:  16477
# Exception at row id:  16479
# Exception at row id:  16482
# Exception at row id:  16523
# Exception at row id:  16527
# Exception at row id:  16556
# Exception at row id:  16559
# Exception at row id:  16568
# Exception at row id:  16584
# Exception at row id:  16586
# Exception at row id:  16642
# Exception at row id:  16654
# Exception at row id:  16728
# Exception at row id:  16779
# Exception at row id:  16812
# Exception at row id:  16832
# Exception at row id:  17074
# Exception at row id:  17103
# Exception at row id:  17180
# Exception at row id:  17281
# Exception at row id:  17337
# Exception at row id:  17392
# Exception at row id:  17460
# Exception at row id:  17475
# Exception at row id:  17482
# Exception at row id:  17522
# Exception at row id:  17533
# Exception at row id:  17554
# Exception at row id:  17575
# Exception at row id:  17587
# Exception at row id:  17588
# Exception at row id:  17589
# Exception at row id:  17640
# Exception at row id:  17699
# Exception at row id:  17715
# Exception at row id:  17809
# Exception at row id:  17998
# Exception at row id:  18003
# Exception at row id:  18077
# Exception at row id:  18083
# Exception at row id:  18089
# Exception at row id:  18127
# Exception at row id:  18138
# Exception at row id:  18144
# Exception at row id:  18146
# Exception at row id:  18159
# Exception at row id:  18182
# Exception at row id:  18216
# Exception at row id:  18319
# Exception at row id:  18367
# Exception at row id:  18408
# Exception at row id:  18493
# Exception at row id:  18509
# Exception at row id:  18512
# Exception at row id:  18657
# Exception at row id:  18669
# Exception at row id:  18678
# Exception at row id:  18689
# Exception at row id:  18709
# Exception at row id:  18740
# Exception at row id:  18742
# Exception at row id:  18744
# Exception at row id:  18789
# Exception at row id:  18811
# Exception at row id:  18844
# Exception at row id:  18853
# Exception at row id:  18857
# Exception at row id:  18891
# Exception at row id:  19074
# Exception at row id:  19131
# Exception at row id:  19165
# Exception at row id:  19236
# Exception at row id:  19248
# Exception at row id:  19279
# Exception at row id:  19292
# Exception at row id:  19299
# Exception at row id:  19378
# Exception at row id:  19436
# Exception at row id:  19455
# Exception at row id:  19581
# Exception at row id:  19600
# Exception at row id:  19602
# Exception at row id:  19655
# Exception at row id:  19854
# Exception at row id:  19861
# Exception at row id:  19888
# Exception at row id:  19899
# Exception at row id:  19918
# Exception at row id:  19967
# Exception at row id:  20033
# Exception at row id:  20108
# Exception at row id:  20134
# Exception at row id:  20143
# Exception at row id:  20218
# Exception at row id:  20321
# Exception at row id:  20359
# Exception at row id:  20378
# Exception at row id:  20379
# Exception at row id:  20469
# Exception at row id:  20500
# Exception at row id:  20508
# Exception at row id:  20687
# Exception at row id:  20748
# Exception at row id:  20757
# Exception at row id:  20813
# Exception at row id:  20816
# Exception at row id:  20874
# Exception at row id:  20906
# Exception at row id:  21018
# Exception at row id:  21022
# Exception at row id:  21033
# Exception at row id:  21067
# Exception at row id:  21084
# Exception at row id:  21141
# Exception at row id:  21186
# Exception at row id:  21188
# Exception at row id:  21203
# Exception at row id:  21237
# Exception at row id:  21391
# Exception at row id:  21397
# Exception at row id:  21439
# Exception at row id:  21469
# Exception at row id:  21496
# Exception at row id:  21521
# Exception at row id:  21533
# Exception at row id:  21535
# Exception at row id:  21615
# Exception at row id:  21618
# Exception at row id:  21677
# Exception at row id:  21682
# Exception at row id:  21701
# Exception at row id:  21758
# Exception at row id:  21767
# Exception at row id:  21772
# Exception at row id:  21801
# Exception at row id:  21808
# Exception at row id:  21885
# Exception at row id:  21962
# Exception at row id:  21972
# Exception at row id:  21978
# Exception at row id:  21986
# Exception at row id:  22033
# Exception at row id:  22058
# Exception at row id:  22071
# Exception at row id:  22170
# Exception at row id:  22244
# Exception at row id:  22268
# Exception at row id:  22281
# Exception at row id:  22286
# Exception at row id:  22330
# Exception at row id:  22355
# Exception at row id:  22414
# Exception at row id:  22436
# Exception at row id:  22441
# Exception at row id:  22447
# Exception at row id:  22459
# Exception at row id:  22461
# Exception at row id:  22469
# Exception at row id:  22486
# Exception at row id:  22519
# Exception at row id:  22541
# Exception at row id:  22593
# Exception at row id:  22594
# Exception at row id:  22613
# Exception at row id:  22640
# Exception at row id:  22642
# Exception at row id:  22656
# Exception at row id:  22674
# Exception at row id:  22682
# Exception at row id:  22740
# Exception at row id:  22757
# Exception at row id:  22758
# Exception at row id:  22775
# Exception at row id:  22848
# Exception at row id:  22887
# Exception at row id:  22962
# Exception at row id:  23113
# Exception at row id:  23126
# Exception at row id:  23136
# Exception at row id:  23146
# Exception at row id:  23147
# Exception at row id:  23167
# Exception at row id:  23209
# Exception at row id:  23210
# Exception at row id:  23262
# Exception at row id:  23366
# Exception at row id:  23384
# Exception at row id:  23387
# Exception at row id:  23417
# Exception at row id:  23457
# Exception at row id:  23508
# Exception at row id:  23532
# Exception at row id:  23550
# Exception at row id:  23551
# Exception at row id:  23558
# Exception at row id:  23587
# Exception at row id:  23631
# Exception at row id:  23726
# Exception at row id:  23737
# Exception at row id:  23802
# Exception at row id:  23875
# Exception at row id:  23999
# Exception at row id:  24000
# Exception at row id:  24171
# Exception at row id:  24231
# Exception at row id:  24239
# Exception at row id:  24268
# Exception at row id:  24394
# Exception at row id:  24448
# Exception at row id:  24556
# Exception at row id:  24568
# Exception at row id:  24594
# Exception at row id:  24747
# Exception at row id:  24862
# Exception at row id:  24866
# Exception at row id:  24885
# Exception at row id:  24911
# Exception at row id:  24958
# Exception at row id:  24975
# Exception at row id:  24980
# Exception at row id:  24993
# Exception at row id:  25030
# Exception at row id:  25078
# Exception at row id:  25081
# Exception at row id:  25207
# Exception at row id:  25208
# Exception at row id:  25260
# Exception at row id:  25323
# Exception at row id:  25331
# Exception at row id:  25337
# Exception at row id:  25342
# Exception at row id:  25360
# Exception at row id:  25369
# Exception at row id:  25373
# Exception at row id:  25425
# Exception at row id:  25427
# Exception at row id:  25450
# Exception at row id:  25475
# Exception at row id:  25480
# Exception at row id:  25512
# Exception at row id:  25553
# Exception at row id:  25629
# Exception at row id:  25648
# Exception at row id:  25696
# Exception at row id:  25848
# Exception at row id:  25852
# Exception at row id:  25876
# Exception at row id:  25896
# Exception at row id:  25915
# Exception at row id:  25961
# Exception at row id:  25972
# Exception at row id:  25976
# Exception at row id:  25989
# Exception at row id:  26063
# Exception at row id:  26081
# Exception at row id:  26090
# Exception at row id:  26141
# Exception at row id:  26184
# Exception at row id:  26194
# Exception at row id:  26203
# Exception at row id:  26238
# Exception at row id:  26302
# Exception at row id:  26315
# Exception at row id:  26337
# Exception at row id:  26368
# Exception at row id:  26426
# Exception at row id:  26435
# Exception at row id:  26464
# Exception at row id:  26465
# Exception at row id:  26482
# Exception at row id:  26510
# Exception at row id:  26511
# Exception at row id:  26525
# Exception at row id:  26527
# Exception at row id:  26585
# Exception at row id:  26587
# Exception at row id:  26596
# Exception at row id:  26642
# Exception at row id:  26688
# Exception at row id:  26701
# Exception at row id:  26745
# Exception at row id:  26753
# Exception at row id:  26766
# Exception at row id:  26868
# Exception at row id:  26893
# Exception at row id:  26936
# Exception at row id:  26954
# Exception at row id:  26986
# Exception at row id:  27020
# Exception at row id:  27024
# Exception at row id:  27027
# Exception at row id:  27037
# Exception at row id:  27074
# Exception at row id:  27116
# Exception at row id:  27137
# Exception at row id:  27152
# Exception at row id:  27247
# Exception at row id:  27282
# Exception at row id:  27388
# Exception at row id:  27391
# Exception at row id:  27397
# Exception at row id:  27412
# Exception at row id:  27425
# Exception at row id:  27446
# Exception at row id:  27504
# Exception at row id:  27597
# Exception at row id:  27625
# Exception at row id:  27634
# Exception at row id:  27716
# Exception at row id:  27754
# Exception at row id:  27774
# Exception at row id:  27827
# Exception at row id:  27856
# Exception at row id:  27902
# Exception at row id:  27942
# Exception at row id:  27965
# Exception at row id:  28016
# Exception at row id:  28020
# Exception at row id:  28058
# Exception at row id:  28061
# Exception at row id:  28080
# Exception at row id:  28094
# Exception at row id:  28117
# Exception at row id:  28317
# Exception at row id:  28324
# Exception at row id:  28325
# Exception at row id:  28355
# Exception at row id:  28375
# Exception at row id:  28447
# Exception at row id:  28517
# Exception at row id:  28574
# Exception at row id:  28588
# Exception at row id:  28600
# Exception at row id:  28621
# Exception at row id:  28675
# Exception at row id:  28767
# Exception at row id:  28801
# Exception at row id:  28857
# Exception at row id:  28900
# Exception at row id:  29022
# Exception at row id:  29027
# Exception at row id:  29093
# Exception at row id:  29104
# Exception at row id:  29228
# Exception at row id:  29250
# Exception at row id:  29263
# Exception at row id:  29323
# Exception at row id:  29432
# Exception at row id:  29546
# Exception at row id:  29560
# Exception at row id:  29589
# Exception at row id:  29700
# Exception at row id:  29722
# Exception at row id:  29733
# Exception at row id:  29756
# Exception at row id:  29821
# Exception at row id:  29836
# Exception at row id:  29867
# Exception at row id:  29872
# Exception at row id:  29911
# Exception at row id:  29932
# Exception at row id:  29964
# Exception at row id:  29979
# Exception at row id:  29984
# Exception at row id:  30025
# Exception at row id:  30032
# Exception at row id:  30083
# Exception at row id:  30089
# Exception at row id:  30090
# Exception at row id:  30114
# Exception at row id:  30119
# Exception at row id:  30144
# Exception at row id:  30219
# Exception at row id:  30269
# Exception at row id:  30306
# Exception at row id:  30330
# Exception at row id:  30438
# Exception at row id:  30457
# Exception at row id:  30467
# Exception at row id:  30499
# Exception at row id:  30517
# Exception at row id:  30527
# Exception at row id:  30549
# Exception at row id:  30553
# Exception at row id:  30576
# Exception at row id:  30582
# Exception at row id:  30653
# Exception at row id:  30699
# Exception at row id:  30707
# Exception at row id:  30719
# Exception at row id:  30722
# Exception at row id:  30746
# Exception at row id:  30905
# Exception at row id:  30910
# Exception at row id:  30913
# Exception at row id:  30964
# Exception at row id:  31008
# Exception at row id:  31018
# Exception at row id:  31052
# Exception at row id:  31110
# Exception at row id:  31112
# Exception at row id:  31124
# Exception at row id:  31192
# Exception at row id:  31198
# Exception at row id:  31205
# Exception at row id:  31232
# Exception at row id:  31244
# Exception at row id:  31380
# Exception at row id:  31394
# Exception at row id:  31410
# Exception at row id:  31450
# Exception at row id:  31453
# Exception at row id:  31537
# Exception at row id:  31538
# Exception at row id:  31604
# Exception at row id:  31637
# Exception at row id:  31693
# Exception at row id:  31707
# Exception at row id:  31765
# Exception at row id:  31767
# Exception at row id:  31818
# Exception at row id:  31864
# Exception at row id:  31887
# Exception at row id:  31915
# Exception at row id:  31929
# Exception at row id:  31930
# Exception at row id:  31946
# Exception at row id:  31965
# Exception at row id:  32020
# Exception at row id:  32024
# Exception at row id:  32039
# Exception at row id:  32067
# Exception at row id:  32078
# Exception at row id:  32132
# Exception at row id:  32161
# Exception at row id:  32174
# Exception at row id:  32185
# Exception at row id:  32200
# Exception at row id:  32248
# Exception at row id:  32282
# Exception at row id:  32342
# Exception at row id:  32419
# Exception at row id:  32453
# Exception at row id:  32484
# Exception at row id:  32510
# Exception at row id:  32520
# Exception at row id:  32525
# Exception at row id:  32528
# Exception at row id:  32543
# Exception at row id:  32551
# Exception at row id:  32580
# Exception at row id:  32622
# Exception at row id:  32629
# Exception at row id:  32633
# Exception at row id:  32681
# Exception at row id:  32704
# Exception at row id:  32742
# Exception at row id:  32773
# Exception at row id:  32813
# Exception at row id:  32850
# Exception at row id:  32859
# Exception at row id:  32989
# Exception at row id:  33000
# Exception at row id:  33122
# Exception at row id:  33224
# Exception at row id:  33296
# Exception at row id:  33443
# Exception at row id:  33487
# Exception at row id:  33575
# Exception at row id:  33605
# Exception at row id:  33613
# Exception at row id:  33620
# Exception at row id:  33661
# Exception at row id:  33663
# Exception at row id:  33698
# Exception at row id:  33724
# Exception at row id:  33762
# Exception at row id:  33768
# Exception at row id:  33769
# Exception at row id:  33903
# Exception at row id:  33932
# Exception at row id:  33952
# Exception at row id:  33983
# Exception at row id:  34002
# Exception at row id:  34029
# Exception at row id:  34036
# Exception at row id:  34076
# Exception at row id:  34157
# Exception at row id:  34159
# Exception at row id:  34201
# Exception at row id:  34236
# Exception at row id:  34360
# Exception at row id:  34489
# Exception at row id:  34539
# Exception at row id:  34541
# Exception at row id:  34613
# Exception at row id:  34617
# Exception at row id:  34719
# Exception at row id:  34721
# Exception at row id:  34730
# Exception at row id:  34777
# Exception at row id:  34881
# Exception at row id:  34904
# Exception at row id:  34953
# Exception at row id:  34980
# Exception at row id:  34986
# Exception at row id:  35018
# Exception at row id:  35147
# Exception at row id:  35149
# Exception at row id:  35202
# Exception at row id:  35203
# Exception at row id:  35252
# Exception at row id:  35264
# Exception at row id:  35282
# Exception at row id:  35315
# Exception at row id:  35327
# Exception at row id:  35418
# Exception at row id:  35434
# Exception at row id:  35467
# Exception at row id:  35508
# Exception at row id:  35521
# Exception at row id:  35575
# Exception at row id:  35590
# Exception at row id:  35591
# Exception at row id:  35597
# Exception at row id:  35664
# Exception at row id:  35685
# Exception at row id:  35733
# Exception at row id:  35753
# Exception at row id:  35767
# Exception at row id:  35779
# Exception at row id:  35801
# Exception at row id:  35829
# Exception at row id:  35879
# Exception at row id:  35888
# Exception at row id:  35909
# Exception at row id:  35910
# Exception at row id:  35926
# Exception at row id:  35943
# Exception at row id:  35951
# Exception at row id:  35979
# Exception at row id:  36024
# Exception at row id:  36054
# Exception at row id:  36055
# Exception at row id:  36069
# Exception at row id:  36176
# Exception at row id:  36190
# Exception at row id:  36299
# Exception at row id:  36402
# Exception at row id:  36409
# Exception at row id:  36478
# Exception at row id:  36482
# Exception at row id:  36528
# Exception at row id:  36659
# Exception at row id:  36723
# Exception at row id:  36747
# Exception at row id:  36935
# Exception at row id:  36942
# Exception at row id:  37003
# Exception at row id:  37122
# Exception at row id:  37134
# Exception at row id:  37285
# Exception at row id:  37456
# Exception at row id:  37534
# Exception at row id:  37545
# Exception at row id:  37578
# Exception at row id:  37703
# Exception at row id:  37756
# Exception at row id:  37778
# Exception at row id:  37902
# Exception at row id:  37997
# Exception at row id:  38036
# Exception at row id:  38115
# Exception at row id:  38146
# Exception at row id:  38195
# Exception at row id:  38199
# Exception at row id:  38227
# Exception at row id:  38228
# Exception at row id:  38330
# Exception at row id:  38383
# Exception at row id:  38386
# Exception at row id:  38400
# Exception at row id:  38476
# Exception at row id:  38505
# Exception at row id:  38519
# Exception at row id:  38716
# Exception at row id:  38757
# Exception at row id:  38765
# Exception at row id:  38775
# Exception at row id:  38837
# Exception at row id:  38905
# Exception at row id:  38908
# Exception at row id:  39007
# Exception at row id:  39012
# Exception at row id:  39063
# Exception at row id:  39133
# Exception at row id:  39177
# Exception at row id:  39189
# Exception at row id:  39221
# Exception at row id:  39223
# Exception at row id:  39230
# Exception at row id:  39247
# Exception at row id:  39279
# Exception at row id:  39286
# Exception at row id:  39328
# Exception at row id:  39404
# Exception at row id:  39422
# Exception at row id:  39430
# Exception at row id:  39486
# Exception at row id:  39511
# Exception at row id:  39531
# Exception at row id:  39538
# Exception at row id:  39554
# Exception at row id:  39560
# Exception at row id:  39567
# Exception at row id:  39615
# Exception at row id:  39630
# Exception at row id:  39645
# Exception at row id:  39677
# Exception at row id:  39695
# Exception at row id:  39707
# Exception at row id:  39715
# Exception at row id:  39746
# Exception at row id:  39750
# Exception at row id:  39874
# Exception at row id:  39877
# Exception at row id:  39907
# Exception at row id:  39927
# Exception at row id:  39939
# Exception at row id:  39984
# Exception at row id:  40002
# Exception at row id:  40056
# Exception at row id:  40088
# Exception at row id:  40190
# Exception at row id:  40240
# Exception at row id:  40298
# Exception at row id:  40307
# Exception at row id:  40321
# Exception at row id:  40326
# Exception at row id:  40331
# Exception at row id:  40425
# Exception at row id:  40504
# Exception at row id:  40525
# Exception at row id:  40537
# Exception at row id:  40543
# Exception at row id:  40579
# Exception at row id:  40763
# Exception at row id:  40768
# Exception at row id:  40779
# Exception at row id:  40926
# Exception at row id:  40951
# Exception at row id:  41050
# Exception at row id:  41135
# Exception at row id:  41178
# Exception at row id:  41183
# Exception at row id:  41199
# Exception at row id:  41226
# Exception at row id:  41228
# Exception at row id:  41232
# Exception at row id:  41298
# Exception at row id:  41344
# Exception at row id:  41348
# Exception at row id:  41350
# Exception at row id:  41392
# Exception at row id:  41397
# Exception at row id:  41416
# Exception at row id:  41438
# Exception at row id:  41482
# Exception at row id:  41501
# Exception at row id:  41505
# Exception at row id:  41526
# Exception at row id:  41575
# Exception at row id:  41576
# Exception at row id:  41585
# Exception at row id:  41608
# Exception at row id:  41609
# Exception at row id:  41616
# Exception at row id:  41638
# Exception at row id:  41682
# Exception at row id:  41717
# Exception at row id:  41831
# Exception at row id:  41874
# Exception at row id:  41934
# Exception at row id:  41987
# Exception at row id:  42078
# Exception at row id:  42086
# Exception at row id:  42151
# Exception at row id:  42153
# Exception at row id:  42155
# Exception at row id:  42225
# Exception at row id:  42240
# Exception at row id:  42262
# Exception at row id:  42514
# Exception at row id:  42546
# Exception at row id:  42593
# Exception at row id:  42627
# Exception at row id:  42640
# Exception at row id:  42647
# Exception at row id:  42656
# Exception at row id:  42788
# Exception at row id:  42832
# Exception at row id:  42854
# Exception at row id:  42969
# Exception at row id:  43020
# Exception at row id:  43028
# Exception at row id:  43055
# Exception at row id:  43138
# Exception at row id:  43151
# Exception at row id:  43165
# Exception at row id:  43221
# Exception at row id:  43232
# Exception at row id:  43293
# Exception at row id:  43298
# Exception at row id:  43327
# Exception at row id:  43357
# Exception at row id:  43387
# Exception at row id:  43448
# Exception at row id:  43455
# Exception at row id:  43466
# Exception at row id:  43500
# Exception at row id:  43513
# Exception at row id:  43584
# Exception at row id:  43588
# Exception at row id:  43625
# Exception at row id:  43634
# Exception at row id:  43642
# Exception at row id:  43675
# Exception at row id:  43718
# Exception at row id:  43762
# Exception at row id:  43808
# Exception at row id:  43919
# Exception at row id:  43920
# Exception at row id:  43963
# Exception at row id:  43986
# Exception at row id:  44040
# Exception at row id:  44045
# Exception at row id:  44072
# Exception at row id:  44109
# Exception at row id:  44187
# Exception at row id:  44229
# Exception at row id:  44242
# Exception at row id:  44259
# Exception at row id:  44290
# Exception at row id:  44300
# Exception at row id:  44324
# Exception at row id:  44389
# Exception at row id:  44458
# Exception at row id:  44507
# Exception at row id:  44526
# Exception at row id:  44637
# Exception at row id:  44662
# Exception at row id:  44686
# Exception at row id:  44707
# Exception at row id:  44708
# Exception at row id:  44774
# Exception at row id:  44799
# Exception at row id:  44845
# Exception at row id:  44891
# Exception at row id:  44913
# Exception at row id:  44951
# Exception at row id:  44979
# Exception at row id:  45001
# Exception at row id:  45007
# Exception at row id:  45137
# Exception at row id:  45277
# Exception at row id:  45305
# Exception at row id:  45308
# Exception at row id:  45328
# Exception at row id:  45332
# Exception at row id:  45341
# Exception at row id:  45399
# Exception at row id:  45404
# Exception at row id:  45621
# Exception at row id:  45682
# Exception at row id:  45818
# Exception at row id:  45887
# Exception at row id:  45889
# Exception at row id:  46008
# Exception at row id:  46027
# Exception at row id:  46052
# Exception at row id:  46137
# Exception at row id:  46171
# Exception at row id:  46198
# Exception at row id:  46200
# Exception at row id:  46225
# Exception at row id:  46253
# Exception at row id:  46325
# Exception at row id:  46347
# Exception at row id:  46349
# Exception at row id:  46358
# Exception at row id:  46363
# Exception at row id:  46385
# Exception at row id:  46411
# Exception at row id:  46435
# Exception at row id:  46521
# Exception at row id:  46604
# Exception at row id:  46667
# Exception at row id:  46670
# Exception at row id:  46717
# Exception at row id:  46746
# Exception at row id:  46785
# Exception at row id:  46859
# Exception at row id:  46863
# Exception at row id:  46864
# Exception at row id:  46895
# Exception at row id:  46923
# Exception at row id:  46978
# Exception at row id:  46998
# Exception at row id:  47028
# Exception at row id:  47030
# Exception at row id:  47059
# Exception at row id:  47098
# Exception at row id:  47100
# Exception at row id:  47160
# Exception at row id:  47248
# Exception at row id:  47261
# Exception at row id:  47375
# Exception at row id:  47376
# Exception at row id:  47379
# Exception at row id:  47383
# Exception at row id:  47492
# Exception at row id:  47547
# Exception at row id:  47615
# Exception at row id:  47713
# Exception at row id:  47728
# Exception at row id:  47729
# Exception at row id:  47867
# Exception at row id:  47947
# Exception at row id:  47958
# Exception at row id:  48012
# Exception at row id:  48027
# Exception at row id:  48028
# Exception at row id:  48057
# Exception at row id:  48078
# Exception at row id:  48179
# Exception at row id:  48181
# Exception at row id:  48278
# Exception at row id:  48372
# Exception at row id:  48385
# Exception at row id:  48411
# Exception at row id:  48542
# Exception at row id:  48562
# Exception at row id:  48573
# Exception at row id:  48600
# Exception at row id:  48608
# Exception at row id:  48642
# Exception at row id:  48658
# Exception at row id:  48700
# Exception at row id:  48705
# Exception at row id:  48719
# Exception at row id:  48730
# Exception at row id:  48791
# Exception at row id:  48801
# Exception at row id:  48821
# Exception at row id:  48828
# Exception at row id:  48831
# Exception at row id:  48883
# Exception at row id:  48942
# Exception at row id:  48974
# Exception at row id:  49054
# Exception at row id:  49108
# Exception at row id:  49338
# Exception at row id:  49377
# Exception at row id:  49398
# Exception at row id:  49451
# Exception at row id:  49473
# Exception at row id:  49498
# Exception at row id:  49508
# Exception at row id:  49596
# Exception at row id:  49602
# Exception at row id:  49666
# Exception at row id:  49695
# Exception at row id:  49705
# Exception at row id:  49726
# Exception at row id:  49729
# Exception at row id:  49757
# Exception at row id:  49790
# Exception at row id:  49794
# Exception at row id:  49816
# Exception at row id:  49966
# Exception at row id:  49969
# Exception at row id:  50067
# Exception at row id:  50079
# Exception at row id:  50163
# Exception at row id:  50173
# Exception at row id:  50182
# Exception at row id:  50191
# Exception at row id:  50222
# Exception at row id:  50230
# Exception at row id:  50287
# Exception at row id:  50293
# Exception at row id:  50345
# Exception at row id:  50355
# Exception at row id:  50514
# Exception at row id:  50519
# Exception at row id:  50581
# Exception at row id:  50655
# Exception at row id:  50665
# Exception at row id:  50724
# Exception at row id:  50749
# Exception at row id:  50805
# Exception at row id:  50823
# Exception at row id:  50835
# Exception at row id:  50856
# Exception at row id:  50886
# Exception at row id:  50903
# Exception at row id:  50916
# Exception at row id:  50969
# Exception at row id:  51006
# Exception at row id:  51023
# Exception at row id:  51087
# Exception at row id:  51089
# Exception at row id:  51102
# Exception at row id:  51282
# Exception at row id:  51381
# Exception at row id:  51407
# Exception at row id:  51449
# Exception at row id:  51524
# Exception at row id:  51558
# Exception at row id:  51588
# Exception at row id:  51669
# Exception at row id:  51681
# Exception at row id:  51791
# Exception at row id:  51839
# Exception at row id:  51875
# Exception at row id:  51906
# Exception at row id:  51928
# Exception at row id:  51959
# Exception at row id:  51963
# Exception at row id:  51973
# Exception at row id:  51988
# Exception at row id:  52007
# Exception at row id:  52034
# Exception at row id:  52046
# Exception at row id:  52050
# Exception at row id:  52055
# Exception at row id:  52102
# Exception at row id:  52171
# Exception at row id:  52180
# Exception at row id:  52270
# Exception at row id:  52300
# Exception at row id:  52312
# Exception at row id:  52396
# Exception at row id:  52507
# Exception at row id:  52547
# Exception at row id:  52580
# Exception at row id:  52587
# Exception at row id:  52629
# Exception at row id:  52664
# Exception at row id:  52778
# Exception at row id:  52829
# Exception at row id:  52866
# Exception at row id:  53051
# Exception at row id:  53105
# Exception at row id:  53140
# Exception at row id:  53161
# Exception at row id:  53211
# Exception at row id:  53218
# Exception at row id:  53255
# Exception at row id:  53322
# Exception at row id:  53338
# Exception at row id:  53342
# Exception at row id:  53363
# Exception at row id:  53426
# Exception at row id:  53432
# Exception at row id:  53453
# Exception at row id:  53478
# Exception at row id:  53570
# Exception at row id:  53571
# Exception at row id:  53586
# Exception at row id:  53587
# Exception at row id:  53593
# Exception at row id:  53624
# Exception at row id:  53629
# Exception at row id:  53632
# Exception at row id:  53643
# Exception at row id:  53678
# Exception at row id:  53687
# Exception at row id:  53725
# Exception at row id:  53742
# Exception at row id:  53756
# Exception at row id:  53757
# Exception at row id:  53768
# Exception at row id:  53774
# Exception at row id:  53786
# Exception at row id:  53873
# Exception at row id:  54026
# Exception at row id:  54106
# Exception at row id:  54119
# Exception at row id:  54158
# Exception at row id:  54232
# Exception at row id:  54233
# Exception at row id:  54266
# Exception at row id:  54300
# Exception at row id:  54371
# Exception at row id:  54435
# Exception at row id:  54446
# Exception at row id:  54454
# Exception at row id:  54463
# Exception at row id:  54465
# Exception at row id:  54474
# Exception at row id:  54500
# Exception at row id:  54524
# Exception at row id:  54565
# Exception at row id:  54576
# Exception at row id:  54657
# Exception at row id:  54702
# Exception at row id:  54716
# Exception at row id:  54741
# Exception at row id:  54772
# Exception at row id:  54784
# Exception at row id:  54797
# Exception at row id:  54852
# Exception at row id:  54888
# Exception at row id:  54936
# Exception at row id:  54940
# Exception at row id:  54965
# Exception at row id:  54975
# Exception at row id:  55044
# Exception at row id:  55109
# Exception at row id:  55123
# Exception at row id:  55149
# Exception at row id:  55172
# Exception at row id:  55209
# Exception at row id:  55245
# Exception at row id:  55331
# Exception at row id:  55377
# Exception at row id:  55403
# Exception at row id:  55409
# Exception at row id:  55456
# Exception at row id:  55458
# Exception at row id:  55502
# Exception at row id:  55552
# Exception at row id:  55557
# Exception at row id:  55565
# Exception at row id:  55566
# Exception at row id:  55628
# Exception at row id:  55659
# Exception at row id:  55697
# Exception at row id:  55723
# Exception at row id:  55787
# Exception at row id:  55788
# Exception at row id:  55870
# Exception at row id:  55971
# Exception at row id:  55982
# Exception at row id:  56044
# Exception at row id:  56063
# Exception at row id:  56086
# Exception at row id:  56095
# Exception at row id:  56103
# Exception at row id:  56179
# Exception at row id:  56250
# Exception at row id:  56253
# Exception at row id:  56312
# Exception at row id:  56319
# Exception at row id:  56326
# Exception at row id:  56386
# Exception at row id:  56390
# Exception at row id:  56439
# Exception at row id:  56470
# Exception at row id:  56485
# Exception at row id:  56512
# Exception at row id:  56514
# Exception at row id:  56570
# Exception at row id:  56640
# Exception at row id:  56652
# Exception at row id:  56662
# Exception at row id:  56688
# Exception at row id:  56693
# Exception at row id:  56803
# Exception at row id:  56869
# Exception at row id:  56870
# Exception at row id:  56881
# Exception at row id:  56886
# Exception at row id:  56928
# Exception at row id:  56971
# Exception at row id:  56983
# Exception at row id:  57002
# Exception at row id:  57010
# Exception at row id:  57020
# Exception at row id:  57044
# Exception at row id:  57060
# Exception at row id:  57063
# Exception at row id:  57070
# Exception at row id:  57074
# Exception at row id:  57076
# Exception at row id:  57116
# Exception at row id:  57259
# Exception at row id:  57297
# Exception at row id:  57299
# Exception at row id:  57331
# Exception at row id:  57390
# Exception at row id:  57455
# Exception at row id:  57471
# Exception at row id:  57476
# Exception at row id:  57516
# Exception at row id:  57521
# Exception at row id:  57534
# Exception at row id:  57535
# Exception at row id:  57542
# Exception at row id:  57561
# Exception at row id:  57607
# Exception at row id:  57616
# Exception at row id:  57625
# Exception at row id:  57638
# Exception at row id:  57641
# Exception at row id:  57655
# Exception at row id:  57686
# Exception at row id:  57723
# Exception at row id:  57769
# Exception at row id:  57774
# Exception at row id:  57783
# Exception at row id:  57871
# Exception at row id:  57930
# Exception at row id:  57990
# Exception at row id:  57991
# Exception at row id:  58007
# Exception at row id:  58032
# Exception at row id:  58034
# Exception at row id:  58090
# Exception at row id:  58101
# Exception at row id:  58134
# Exception at row id:  58157
# Exception at row id:  58170
# Exception at row id:  58180
# Exception at row id:  58181
# Exception at row id:  58189
# Exception at row id:  58257
# Exception at row id:  58279
# Exception at row id:  58303
# Exception at row id:  58333
# Exception at row id:  58337
# Exception at row id:  58384
# Exception at row id:  58403
# Exception at row id:  58416
# Exception at row id:  58427
# Exception at row id:  58429
# Exception at row id:  58456
# Exception at row id:  58555
# Exception at row id:  58623
# Exception at row id:  58678
# Exception at row id:  58745
# Exception at row id:  58801
# Exception at row id:  58840
# Exception at row id:  58897
# Exception at row id:  58908
# Exception at row id:  59009
# Exception at row id:  59012
# Exception at row id:  59013
# Exception at row id:  59027
# Exception at row id:  59051
# Exception at row id:  59102
# Exception at row id:  59116
# Exception at row id:  59140
# Exception at row id:  59319
# Exception at row id:  59337
# Exception at row id:  59395
# Exception at row id:  59439
# Exception at row id:  59513
# Exception at row id:  59518
# Exception at row id:  59568
# Exception at row id:  59633
# Exception at row id:  59669
# Exception at row id:  59674
# Exception at row id:  59691
# Exception at row id:  59707
# Exception at row id:  59709
# Exception at row id:  59722
# Exception at row id:  59726
# Exception at row id:  59779
# Exception at row id:  59897
# Exception at row id:  60148
# Exception at row id:  60176
# Exception at row id:  60208
# Exception at row id:  60279
# Exception at row id:  60284
# Exception at row id:  60290
# Exception at row id:  60309
# Exception at row id:  60339
# Exception at row id:  60383
# Exception at row id:  60494
# Exception at row id:  60500
# Exception at row id:  60502
# Exception at row id:  60504
# Exception at row id:  60573
# Exception at row id:  60574
# Exception at row id:  60719
# Exception at row id:  60763
# Exception at row id:  60770
# Exception at row id:  60780
# Exception at row id:  60834
# Exception at row id:  60854
# Exception at row id:  60878
# Exception at row id:  60879
# Exception at row id:  60910
# Exception at row id:  60957
# Exception at row id:  60967
# Exception at row id:  61035
# Exception at row id:  61036
# Exception at row id:  61041
# Exception at row id:  61075
# Exception at row id:  61118
# Exception at row id:  61183
# Exception at row id:  61192
# Exception at row id:  61248
# Exception at row id:  61304
# Exception at row id:  61326
# Exception at row id:  61389
# Exception at row id:  61395
# Exception at row id:  61513
# Exception at row id:  61515
# Exception at row id:  61564
# Exception at row id:  61568
# Exception at row id:  61658
# Exception at row id:  61670
# Exception at row id:  61735
# Exception at row id:  61746
# Exception at row id:  61752
# Exception at row id:  61780
# Exception at row id:  61792
# Exception at row id:  61899
# Exception at row id:  61958
# Exception at row id:  61975
# Exception at row id:  62028
# Exception at row id:  62064
# Exception at row id:  62123
# Exception at row id:  62139
# Exception at row id:  62194
# Exception at row id:  62234
# Exception at row id:  62266
# Exception at row id:  62296
# Exception at row id:  62299
# Exception at row id:  62357
# Exception at row id:  62358
# Exception at row id:  62382
# Exception at row id:  62387
# Exception at row id:  62404
# Exception at row id:  62436
# Exception at row id:  62449
# Exception at row id:  62478
# Exception at row id:  62481
# Exception at row id:  62498
# Exception at row id:  62589
# Exception at row id:  62606
# Exception at row id:  62608
# Exception at row id:  62626
# Exception at row id:  62633
# Exception at row id:  62673
# Exception at row id:  62694
# Exception at row id:  62730
# Exception at row id:  62743
# Exception at row id:  62784
# Exception at row id:  62837
# Exception at row id:  62846
# Exception at row id:  62870
# Exception at row id:  62962
# Exception at row id:  62970
# Exception at row id:  62974
# Exception at row id:  62980
# Exception at row id:  62982
# Exception at row id:  63012
# Exception at row id:  63015
# Exception at row id:  63035
# Exception at row id:  63045
# Exception at row id:  63120
# Exception at row id:  63141
# Exception at row id:  63161
# Exception at row id:  63198
# Exception at row id:  63240
# Exception at row id:  63277
# Exception at row id:  63284
# Exception at row id:  63302
# Exception at row id:  63316
# Exception at row id:  63319
# Exception at row id:  63436
# Exception at row id:  63471
# Exception at row id:  63490
# Exception at row id:  63506
# Exception at row id:  63757
# Exception at row id:  63766
# Exception at row id:  63767
# Exception at row id:  63779
# Exception at row id:  63823
# Exception at row id:  63913
# Exception at row id:  63921
# Exception at row id:  63969
# Exception at row id:  63982
# Exception at row id:  64006
# Exception at row id:  64066
# Exception at row id:  64100
# Exception at row id:  64101
# Exception at row id:  64116
# Exception at row id:  64136
# Exception at row id:  64253
# Exception at row id:  64257
# Exception at row id:  64412
# Exception at row id:  64430
# Exception at row id:  64434
# Exception at row id:  64445
# Exception at row id:  64510
# Exception at row id:  64567
# Exception at row id:  64574
# Exception at row id:  64604
# Exception at row id:  64607
# Exception at row id:  64622
# Exception at row id:  64641
# Exception at row id:  64757
# Exception at row id:  64759
# Exception at row id:  64914
# Exception at row id:  64933
# Exception at row id:  64936
# Exception at row id:  64949
# Exception at row id:  65013
# Exception at row id:  65071
# Exception at row id:  65120
# Exception at row id:  65190
# Exception at row id:  65197
# Exception at row id:  65253
# Exception at row id:  65289
# Exception at row id:  65343
# Exception at row id:  65379
# Exception at row id:  65449
# Exception at row id:  65534
# Exception at row id:  65552
# Exception at row id:  65593
# Exception at row id:  65623
# Exception at row id:  65624
# Exception at row id:  65655
# Exception at row id:  65698
# Exception at row id:  65722
# Exception at row id:  65866
# Exception at row id:  65891
# Exception at row id:  65951
# Exception at row id:  66014
# Exception at row id:  66032
# Exception at row id:  66071
# Exception at row id:  66127
# Exception at row id:  66150
# Exception at row id:  66182
# Exception at row id:  66197
# Exception at row id:  66201
# Exception at row id:  66262
# Exception at row id:  66354
# Exception at row id:  66396
# Exception at row id:  66441
# Exception at row id:  66522
# Exception at row id:  66532
# Exception at row id:  66557
# Exception at row id:  66625
# Exception at row id:  66734
# Exception at row id:  66798
# Exception at row id:  66800
# Exception at row id:  66851
# Exception at row id:  66970
# Exception at row id:  66971
# Exception at row id:  66976
# Exception at row id:  66983
# Exception at row id:  67036
# Exception at row id:  67092
# Exception at row id:  67100
# Exception at row id:  67160
# Exception at row id:  67205
# Exception at row id:  67258
# Exception at row id:  67268
# Exception at row id:  67299
# Exception at row id:  67329
# Exception at row id:  67394
# Exception at row id:  67397
# Exception at row id:  67407
# Exception at row id:  67409
# Exception at row id:  67416
# Exception at row id:  67497
# Exception at row id:  67501
# Exception at row id:  67583
# Exception at row id:  67614
# Exception at row id:  67634
# Exception at row id:  67642
# Exception at row id:  67670
# Exception at row id:  67685
# Exception at row id:  67698
# Exception at row id:  67704
# Exception at row id:  67720
# Exception at row id:  67733
# Exception at row id:  67739
# Exception at row id:  67817
# Exception at row id:  67924
# Exception at row id:  68002
# Exception at row id:  68012
# Exception at row id:  68023
# Exception at row id:  68060
# Exception at row id:  68127
# Exception at row id:  68162
# Exception at row id:  68196
# Exception at row id:  68322
# Exception at row id:  68324
# Exception at row id:  68391
# Exception at row id:  68397
# Exception at row id:  68430
# Exception at row id:  68442
# Exception at row id:  68460
# Exception at row id:  68472
# Exception at row id:  68474
# Exception at row id:  68532
# Exception at row id:  68534
# Exception at row id:  68547
# Exception at row id:  68564
# Exception at row id:  68611
# Exception at row id:  68681
# Exception at row id:  68744
# Exception at row id:  68760
# Exception at row id:  68787
# Exception at row id:  68832
# Exception at row id:  68896
# Exception at row id:  68903
# Exception at row id:  68937
# Exception at row id:  69077
# Exception at row id:  69087
# Exception at row id:  69116
# Exception at row id:  69139
# Exception at row id:  69168
# Exception at row id:  69204
# Exception at row id:  69236
# Exception at row id:  69274
# Exception at row id:  69286
# Exception at row id:  69322
# Exception at row id:  69350
# Exception at row id:  69380
# Exception at row id:  69438
# Exception at row id:  69448
# Exception at row id:  69489
# Exception at row id:  69540
# Exception at row id:  69562
# Exception at row id:  69577
# Exception at row id:  69616
# Exception at row id:  69642
# Exception at row id:  69646
# Exception at row id:  69658
# Exception at row id:  69659
# Exception at row id:  69662
# Exception at row id:  69751
# Exception at row id:  69762
# Exception at row id:  69824
# Exception at row id:  69829
# Exception at row id:  69882
# Exception at row id:  69908
# Exception at row id:  69927
# Exception at row id:  69929
# Exception at row id:  69930
# Exception at row id:  69998
# Exception at row id:  70045
# Exception at row id:  70066
# Exception at row id:  70073
# Exception at row id:  70094
# Exception at row id:  70213
# Exception at row id:  70248
# Exception at row id:  70253
# Exception at row id:  70263
# Exception at row id:  70270
# Exception at row id:  70273
# Exception at row id:  70315
# Exception at row id:  70405
# Exception at row id:  70462
# Exception at row id:  70470
# Exception at row id:  70573
# Exception at row id:  70589
# Exception at row id:  70616
# Exception at row id:  70672
# Exception at row id:  70820
# Exception at row id:  71045
# Exception at row id:  71055
# Exception at row id:  71118
# Exception at row id:  71227
# Exception at row id:  71228
# Exception at row id:  71293
# Exception at row id:  71350
# Exception at row id:  71401
# Exception at row id:  71440
# Exception at row id:  71449
# Exception at row id:  71531
# Exception at row id:  71613
# Exception at row id:  71628
# Exception at row id:  71630
# Exception at row id:  71631
# Exception at row id:  71635
# Exception at row id:  71665
# Exception at row id:  71736
# Exception at row id:  71749
# Exception at row id:  71751
# Exception at row id:  71827
# Exception at row id:  71914
# Exception at row id:  71931
# Exception at row id:  71951
# Exception at row id:  71952
# Exception at row id:  72000
# Exception at row id:  72003
# Exception at row id:  72021
# Exception at row id:  72043
# Exception at row id:  72106
# Exception at row id:  72264
# Exception at row id:  72281
# Exception at row id:  72301
# Exception at row id:  72321
# Exception at row id:  72327
# Exception at row id:  72332
# Exception at row id:  72339
# Exception at row id:  72366
# Exception at row id:  72372
# Exception at row id:  72399
# Exception at row id:  72407
# Exception at row id:  72451
# Exception at row id:  72499
# Exception at row id:  72504
# Exception at row id:  72507
# Exception at row id:  72538
# Exception at row id:  72539
# Exception at row id:  72549
# Exception at row id:  72567
# Exception at row id:  72579
# Exception at row id:  72683
# Exception at row id:  72684
# Exception at row id:  72739
# Exception at row id:  72769
# Exception at row id:  72841
# ...
# Exception at row id:  169938
# Exception at row id:  169987
# Exception at row id:  170011
# Exception at row id:  170013
# Exception at row id:  170040
# Exception at row id:  170143
# Exception at row id:  170162
# Exception at row id:  170169
# Exception at row id:  170179
# Exception at row id:  170276
# Exception at row id:  170332
# Exception at row id:  170396
# Exception at row id:  170404
# Exception at row id:  170442
# Exception at row id:  170480
# Exception at row id:  170532
# Exception at row id:  170586
# Exception at row id:  170587
# Exception at row id:  170657
# Exception at row id:  170664
# Exception at row id:  170671
# Exception at row id:  170677
# Exception at row id:  170721
# Exception at row id:  170830
# Exception at row id:  170854
# Exception at row id:  171018
# Exception at row id:  171050
# Exception at row id:  171111
# Exception at row id:  171121
# Exception at row id:  171125
# Exception at row id:  171184
# Exception at row id:  171260
# Exception at row id:  171267
# Exception at row id:  171310
# Exception at row id:  171384
# Exception at row id:  171492
# Exception at row id:  171494
# Exception at row id:  171698
# Exception at row id:  171761
# Exception at row id:  171833
# Exception at row id:  171847
# Exception at row id:  171871
# Exception at row id:  171967
# Exception at row id:  172001
# Exception at row id:  172151
# Exception at row id:  172158
# Exception at row id:  172176
# Exception at row id:  172212
# Exception at row id:  172220
# Exception at row id:  172271
# Exception at row id:  172295
# Exception at row id:  172383
# Exception at row id:  172408
# Exception at row id:  172409
# Exception at row id:  172446
# Exception at row id:  172484
# Exception at row id:  172506
# Exception at row id:  172520
# Exception at row id:  172525
# Exception at row id:  172540
# Exception at row id:  172564
# Exception at row id:  172625
# Exception at row id:  172669
# Exception at row id:  172673
# Exception at row id:  172772
# Exception at row id:  172789
# Exception at row id:  172822
# Exception at row id:  172839
# Exception at row id:  172849
# Exception at row id:  172907
# Exception at row id:  172928
# Exception at row id:  172931
# Exception at row id:  172937
# Exception at row id:  172940
# Exception at row id:  172972
# Exception at row id:  172987
# Exception at row id:  173101
# Exception at row id:  173117
# Exception at row id:  173126
# Exception at row id:  173134
# Exception at row id:  173135
# Exception at row id:  173143
# Exception at row id:  173152
# Exception at row id:  173178
# Exception at row id:  173200
# Exception at row id:  173220
# Exception at row id:  173240
# Exception at row id:  173246
# Exception at row id:  173257
# Exception at row id:  173290
# Exception at row id:  173294
# Exception at row id:  173313
# Exception at row id:  173356
# Exception at row id:  173375
# Exception at row id:  173387
# Exception at row id:  173460
# Exception at row id:  173464
# Exception at row id:  173515
# Exception at row id:  173556
# Exception at row id:  173571
# Exception at row id:  173644
# Exception at row id:  173737
# Exception at row id:  173745
# Exception at row id:  173773
# Exception at row id:  173792
# Exception at row id:  173798
# Exception at row id:  173804
# Exception at row id:  173822
# Exception at row id:  173882
# Exception at row id:  173884
# Exception at row id:  173918
# Exception at row id:  173927
# Exception at row id:  173978
# Exception at row id:  173986
# Exception at row id:  173987
# Exception at row id:  173989
# Exception at row id:  174024
# Exception at row id:  174045
# Exception at row id:  174061
# Exception at row id:  174063
# Exception at row id:  174083
# Exception at row id:  174113
# Exception at row id:  174193
# Exception at row id:  174199
# Exception at row id:  174263
# Exception at row id:  174281
# Exception at row id:  174305
# Exception at row id:  174313
# Exception at row id:  174364
# Exception at row id:  174383
# Exception at row id:  174452
# Exception at row id:  174460
# Exception at row id:  174518
# Exception at row id:  174558
# Exception at row id:  174574
# Exception at row id:  174680
# Exception at row id:  174751
# Exception at row id:  174769
# Exception at row id:  174800
# Exception at row id:  174816
# Exception at row id:  174822
# Exception at row id:  174831
# Exception at row id:  174833
# Exception at row id:  174846
# Exception at row id:  174847
# Exception at row id:  174860
# Exception at row id:  174875
# Exception at row id:  174918
# Exception at row id:  174949
# Exception at row id:  174955
# Exception at row id:  174968
# Exception at row id:  175013
# Exception at row id:  175042
# Exception at row id:  175072
# Exception at row id:  175083
# Exception at row id:  175129
# Exception at row id:  175155
# Exception at row id:  175177
# Exception at row id:  175186
# Exception at row id:  175230
# Exception at row id:  175296
# Exception at row id:  175318
# Exception at row id:  175330
# Exception at row id:  175335
# Exception at row id:  175404
# Exception at row id:  175535
# Exception at row id:  175568
# Exception at row id:  175569
# Exception at row id:  175595
# Exception at row id:  175598
# Exception at row id:  175614
# Exception at row id:  175616
# Exception at row id:  175657
# Exception at row id:  175734
# Exception at row id:  175771
# Exception at row id:  175841
# Exception at row id:  175859
# Exception at row id:  175923
# Exception at row id:  175925
# Exception at row id:  175999
# Exception at row id:  176017
# Exception at row id:  176037
# Exception at row id:  176154
# Exception at row id:  176174
# Exception at row id:  176190
# Exception at row id:  176235
# Exception at row id:  176256
# Exception at row id:  176263
# Exception at row id:  176307
# Exception at row id:  176326
# Exception at row id:  176447
# Exception at row id:  176496
# Exception at row id:  176506
# Exception at row id:  176530
# Exception at row id:  176539
# Exception at row id:  176545
# Exception at row id:  176576
# Exception at row id:  176601
# Exception at row id:  176602
# Exception at row id:  176604
# Exception at row id:  176656
# Exception at row id:  176685
# Exception at row id:  176694
# Exception at row id:  176755
# Exception at row id:  176797
# Exception at row id:  176819
# Exception at row id:  176871
# Exception at row id:  177001
# Exception at row id:  177008
# Exception at row id:  177014
# Exception at row id:  177016
# Exception at row id:  177050
# Exception at row id:  177065
# Exception at row id:  177073
# Exception at row id:  177074
# Exception at row id:  177097
# Exception at row id:  177149
# Exception at row id:  177242
# Exception at row id:  177270
# Exception at row id:  177291
# Exception at row id:  177321
# Exception at row id:  177361
# Exception at row id:  177425
# Exception at row id:  177455
# Exception at row id:  177523
# Exception at row id:  177558
# Exception at row id:  177564
# Exception at row id:  177572
# Exception at row id:  177612
# Exception at row id:  177625
# Exception at row id:  177626
# Exception at row id:  177632
# Exception at row id:  177687
# Exception at row id:  177698
# Exception at row id:  177703
# Exception at row id:  177714
# Exception at row id:  177740
# Exception at row id:  177868
# Exception at row id:  177884
# Exception at row id:  177954
# Exception at row id:  177985
# Exception at row id:  178021
# Exception at row id:  178031
# Exception at row id:  178044
# Exception at row id:  178047
# Exception at row id:  178090
# Exception at row id:  178187
# Exception at row id:  178189
# Exception at row id:  178209
# Exception at row id:  178229
# Exception at row id:  178373
# Exception at row id:  178399
# Exception at row id:  178410
# Exception at row id:  178416
# Exception at row id:  178485
# Exception at row id:  178570
# Exception at row id:  178674
# Exception at row id:  178726
# Exception at row id:  178814
# Exception at row id:  178856
# Exception at row id:  178870
# Exception at row id:  178877
# Exception at row id:  178886
# Exception at row id:  178921
# Exception at row id:  178955
# Exception at row id:  178960
# Exception at row id:  178994
# Exception at row id:  179020
# Exception at row id:  179050
# Exception at row id:  179089
# Exception at row id:  179183
# Exception at row id:  179192
# Exception at row id:  179241
# Exception at row id:  179293
# Exception at row id:  179325
# Exception at row id:  179351
# Exception at row id:  179370
# Exception at row id:  179399
# Exception at row id:  179447
# Exception at row id:  179659
# Exception at row id:  179762
# Exception at row id:  179861
# Exception at row id:  179887
# Exception at row id:  179908
# Exception at row id:  179916
# Exception at row id:  179948
# Exception at row id:  179949
# Exception at row id:  179967
# Exception at row id:  180010
# Exception at row id:  180026
# Exception at row id:  180027
# Exception at row id:  180037
# Exception at row id:  180039
# Exception at row id:  180066
# Exception at row id:  180099
# Exception at row id:  180130
# Exception at row id:  180305
# Exception at row id:  180307
# Exception at row id:  180310
# Exception at row id:  180333
# Exception at row id:  180399
# Exception at row id:  180419
# Exception at row id:  180445
# Exception at row id:  180503
# Exception at row id:  180559
# Exception at row id:  180560
# Exception at row id:  180589
# Exception at row id:  180592
# Exception at row id:  180633
# Exception at row id:  180634
# Exception at row id:  180677
# Exception at row id:  180697
# Exception at row id:  180699
# Exception at row id:  180748
# Exception at row id:  180767
# Exception at row id:  180803
# Exception at row id:  180902
# Exception at row id:  180962
# Exception at row id:  180978
# Exception at row id:  181017
# Exception at row id:  181113
# Exception at row id:  181250
# Exception at row id:  181299
# Exception at row id:  181337
# Exception at row id:  181354
# Exception at row id:  181504
# Exception at row id:  181566
# Exception at row id:  181600
# Exception at row id:  181610
# Exception at row id:  181611
# Exception at row id:  181760
# Exception at row id:  181796
# Exception at row id:  181825
# Exception at row id:  181832
# Exception at row id:  181893
# Exception at row id:  181901
# Exception at row id:  181923
# Exception at row id:  182042
# Exception at row id:  182057
# Exception at row id:  182066
# Exception at row id:  182070
# Exception at row id:  182107
# Exception at row id:  182136
# Exception at row id:  182249
# Exception at row id:  182285
# Exception at row id:  182293
# Exception at row id:  182366
# Exception at row id:  182384
# Exception at row id:  182392
# Exception at row id:  182465
# Exception at row id:  182555
# Exception at row id:  182558
# Exception at row id:  182562
# Exception at row id:  182583
# Exception at row id:  182608
# Exception at row id:  182669
# Exception at row id:  182709
# Exception at row id:  182749
# Exception at row id:  182765
# Exception at row id:  182768
# Exception at row id:  182769
# Exception at row id:  182778
# Exception at row id:  182806
# Exception at row id:  182834
# Exception at row id:  182878
# Exception at row id:  182927
# Exception at row id:  182962
# Exception at row id:  183034
# Exception at row id:  183055
# Exception at row id:  183104
# Exception at row id:  183128
# Exception at row id:  183131
# Exception at row id:  183145
# Exception at row id:  183161
# Exception at row id:  183176
# Exception at row id:  183190
# Exception at row id:  183196
# Exception at row id:  183277
# Exception at row id:  183279
# Exception at row id:  183340
# Exception at row id:  183344
# Exception at row id:  183382
# Exception at row id:  183407
# Exception at row id:  183432
# Exception at row id:  183575
# Exception at row id:  183588
# Exception at row id:  183609
# Exception at row id:  183612
# Exception at row id:  183662
# Exception at row id:  183671
# Exception at row id:  183738
# Exception at row id:  183744
# Exception at row id:  183829
# Exception at row id:  183855
# Exception at row id:  183857
# Exception at row id:  183864
# Exception at row id:  183868
# Exception at row id:  183874
# Exception at row id:  183881
# Exception at row id:  183901
# Exception at row id:  183934
# Exception at row id:  183939
# Exception at row id:  183941
# Exception at row id:  183952
# Exception at row id:  183998
# Exception at row id:  184010
# Exception at row id:  184028
# Exception at row id:  184090
# Exception at row id:  184102
# Exception at row id:  184132
# Exception at row id:  184167
# Exception at row id:  184201
# Exception at row id:  184203
# Exception at row id:  184296
# Exception at row id:  184308
# Exception at row id:  184335
# Exception at row id:  184363
# Exception at row id:  184367
# Exception at row id:  184370
# Exception at row id:  184466
# Exception at row id:  184530
# Exception at row id:  184532
# Exception at row id:  184533
# Exception at row id:  184539
# Exception at row id:  184554
# Exception at row id:  184591
# Exception at row id:  184611
# Exception at row id:  184633
# Exception at row id:  184648
# Exception at row id:  184652
# Exception at row id:  184687
# Exception at row id:  184697
# Exception at row id:  184770
# Exception at row id:  184784
# Exception at row id:  184801
# Exception at row id:  184826
# Exception at row id:  184882
# Exception at row id:  184894
# Exception at row id:  185010
# Exception at row id:  185078
# Exception at row id:  185083
# Exception at row id:  185103
# Exception at row id:  185135
# Exception at row id:  185147
# Exception at row id:  185180
# Exception at row id:  185199
# Exception at row id:  185327
# Exception at row id:  185332
# Exception at row id:  185384
# Exception at row id:  185481
# Exception at row id:  185512
# Exception at row id:  185535
# Exception at row id:  185567
# Exception at row id:  185622
# Exception at row id:  185623
# Exception at row id:  185636
# Exception at row id:  185650
# Exception at row id:  185676
# Exception at row id:  185683
# Exception at row id:  185687
# Exception at row id:  185812
# Exception at row id:  185917
# Exception at row id:  185955
# Exception at row id:  186025
# Exception at row id:  186047
# Exception at row id:  186056
# Exception at row id:  186068
# Exception at row id:  186079
# Exception at row id:  186132
# Exception at row id:  186138
# Exception at row id:  186220
# Exception at row id:  186362
# Exception at row id:  186388
# Exception at row id:  186392
# Exception at row id:  186476
# Exception at row id:  186484
# Exception at row id:  186511
# Exception at row id:  186626
# Exception at row id:  186629
# Exception at row id:  186637
# Exception at row id:  186654
# Exception at row id:  186723
# Exception at row id:  186748
# Exception at row id:  186861
# Exception at row id:  186873
# Exception at row id:  186930
# Exception at row id:  186999
# Exception at row id:  187005
# Exception at row id:  187057
# Exception at row id:  187080
# Exception at row id:  187104
# Exception at row id:  187136
# Exception at row id:  187160
# Exception at row id:  187183
# Exception at row id:  187200
# Exception at row id:  187220
# Exception at row id:  187250
# Exception at row id:  187269
# Exception at row id:  187347
# Exception at row id:  187433
# Exception at row id:  187452
# Exception at row id:  187498
# Exception at row id:  187502
# Exception at row id:  187538
# Exception at row id:  187559
# Exception at row id:  187614
# Exception at row id:  187672
# Exception at row id:  187673
# Exception at row id:  187693
# Exception at row id:  187714
# Exception at row id:  187876
# Exception at row id:  187902
# Exception at row id:  187908
# Exception at row id:  187927
# Exception at row id:  187935
# Exception at row id:  187945
# Exception at row id:  187986
# Exception at row id:  188023
# Exception at row id:  188071
# Exception at row id:  188105
# Exception at row id:  188125
# Exception at row id:  188190
# Exception at row id:  188262
# Exception at row id:  188426
# Exception at row id:  188432
# Exception at row id:  188450
# Exception at row id:  188471
# Exception at row id:  188493
# Exception at row id:  188503
# Exception at row id:  188512
# Exception at row id:  188520
# Exception at row id:  188543
# Exception at row id:  188604
# Exception at row id:  188633
# Exception at row id:  188674
# Exception at row id:  188689
# Exception at row id:  188817
# Exception at row id:  188877
# Exception at row id:  188894
# Exception at row id:  188941
# Exception at row id:  188975
# Exception at row id:  188997
# Exception at row id:  189010
# Exception at row id:  189036
# Exception at row id:  189071
# Exception at row id:  189126
# Exception at row id:  189147
# Exception at row id:  189161
# Exception at row id:  189167
# Exception at row id:  189203
# Exception at row id:  189268
# 0 92991 91044

# %% [markdown]
# ### remove duplicates and resave the matched files. combine them to form one consolidated elastic search match file

# %%
# find the count of matches in each config file
import pandas as pd

test_match_allcond = pd.read_csv("/content/test_match_allcond.csv", error_bad_lines=False, header = None) # match with all conditions
#test_match_noward = pd.read_csv("/content/test_match_noward.csv", error_bad_lines=False, header = None) # match after removing ward no
test_match_nonamematch = pd.read_csv("/content/test_match_nonamematch.csv", error_bad_lines=False, header = None) # match with ward no and metaphones
#test_match_onlymetaphone = pd.read_csv("/content/test_match_onlymetaphone.csv", error_bad_lines=False, header = None) # match with only metaphones
test_nomatch = pd.read_csv("/content/test-u.csv", error_bad_lines=False, header = None) # non matched cd records
test_match = pd.read_csv("/content/test.csv", error_bad_lines=False, delimiter='\t') # matched information

# remove duplicates
test_match_allcond.drop_duplicates(inplace=True)
#test_match_noward.drop_duplicates(inplace=True)
test_match_nonamematch.drop_duplicates(inplace=True)
#test_match_onlymetaphone.drop_duplicates(inplace=True)
test_nomatch.drop_duplicates(inplace=True)
test_match.drop_duplicates(inplace=True)

print(len(test_match_allcond))
#print(len(test_match_noward)) # no ward
print(len(test_match_nonamematch)) # uses ward no, ed and metaphones
#print(len(test_match_onlymetaphone)) # no ward, first and last names
print(len(test_nomatch))
print(len(test_match))
# Out:
# b'Skipping line 1103: expected 1 fields, saw 2\nSkipping line 1477: expected 1 fields, saw 2\nSkipping line 1660: expected 1 fields, saw 2\nSkipping line 5518: expected 1 fields, saw 2\nSkipping line 17260: expected 1 fields, saw 2\nSkipping line 17954: expected 1 fields, saw 2\nSkipping line 18701: expected 1 fields, saw 2\nSkipping line 19197: expected 1 fields, saw 2\nSkipping line
# 81115
# 11825
# 90888
# 120020

# %%
# save all the files again

test_match_allcond.to_csv("/content/test_match_allcond.csv", index= False)
#test_match_noward.to_csv("/content/test_match_noward.csv", index= False)
test_match_nonamematch.to_csv("/content/test_match_nonamematch.csv", index= False)
#test_match_onlymetaphone.to_csv("/content/test_match_onlymetaphone.csv", index= False)
test_nomatch.to_csv("/content/test-u.csv", index= False)
test_match.to_csv("/content/test_matched.csv", index= False)

# %% [markdown]
# # 1850 mn elastic search

# %%
server = Popen(['elasticsearch-7.8.1/bin/elasticsearch'], stdout=PIPE, stderr=STDOUT, preexec_fn=lambda: os.setuid(1))
# !sleep 30

# %% [markdown]
# ### replicate work done by previosu RAs

# %% [markdown]
# ##### data ingestion

# %%
# data ingestion

es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename="/content/bulk_insert.log",
                            filemode='a',
                            format='%(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('InsertTime')

def ingest(config):
    df = pd.read_csv(config['census_filename'])
    bulk_data = []
    count = 0 
    for itr, row in df.iterrows():
        count+=1
        row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
        data = row.to_dict() #converts the dataframe row to dictonary with their correct data type
        if 'LOCATION' in data:
          data['LOCATION'] = {"lat":data["LAT"],"lon":data["LONG"]}
        
        if 'ADDNUMFROM' in data and type(data['ADDNUMFROM']) is str:
            data['ADDNUMFROM'] = data['ADDNUMFROM'].replace('`','')

        data[config['census_first_name']] = name_clean(data[config['census_first_name']])
        data[config['census_last_name']] = name_clean(data[config['census_last_name']])
        
        if config['metaphone'] is 1:
          data['METAPHONE_NAMEFIRST'] = [i for i in doublemetaphone(data[config['census_first_name']]) if i]
          data['METAPHONE_NAMELAST'] = [i for i in doublemetaphone(data[config['census_last_name']]) if i]
        
        if id is not False:
          meta = {
              "_index": config['es-index'],
              "_id": data[config['es-id']],
              "_source": data
          }
        else:
          meta = {
              "_index": config['es-index'],
              "_source": data
          }

        bulk_data.append(meta)
        if itr%config['ingest_size'] == 0:
            helpers.bulk(es, bulk_data)
            bulk_data = []
            print("INSERTING NOW", itr)
            
    helpers.bulk(es, bulk_data)
    return count

def name_clean(name):
  return max(name.split(' '), key=len)

if __name__=='__main__':
    if __name__ == '__main__':
      #parser = ArgumentParser()
      #parser.add_argument("-config", help="config file path", default="/content/config_1850.json")

      #args = parser.parse_args()

      #with open(args.config) as json_data_file:
      #  config = json.load(json_data_file)
      with open('/content/config_1850.json') as json_data_file:
         config = json.load(json_data_file)


      st = time.time()
      ingest(config)
      end = time.time()
      logger.warning(config["es-index"] +" "+ str(end-st))
 
#Mapping used
'''
PUT census
{
    "mappings" : {
      "properties" : {
        "ADDNUM" : {
          "type" : "long"
        },
        "ADDNUMFROM" : {
          "type" : "long"
        },
        "ADDNUMTO" : {
          "type" : "long"
        },
        "ADDR_TYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ADDRESSB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_AGEB" : {
          "type" : "long"
        },
        "CENSUS_BUILDING_I" : {
          "type" : "long"
        },
        "CENSUS_CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ED" : {
          "type" : "long"
        },
        "CENSUS_ENUMDISTB" : {
          "type" : "long"
        },
        "CENSUS_EXTGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_FID" : {
          "type" : "long"
        },
        "CENSUS_MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_MERGEID" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMEFRSTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMELASTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NEIGHBOR_1" : {
          "type" : "long"
        },
        "CENSUS_NEIGHBOR_2" : {
          "type" : "long"
        },
        "CENSUS_NPERHHB" : {
          "type" : "long"
        },
        "CENSUS_OCCLABELB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_PAGENUMB" : {
          "type" : "long"
        },
        "CENSUS_RACEB" : {
          "type" : "long"
        },
        "CENSUS_RACENAMEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_REELB" : {
          "type" : "long"
        },
        "CENSUS_RELATEB" : {
          "type" : "long"
        },
        "CENSUS_RELATE_STR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_SEGGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_SEGMENT_ID" : {
          "type" : "long"
        },
        "CENSUS_SERIAL" : {
          "type" : "long"
        },
        "CENSUS_SERIALB" : {
          "type" : "long"
        },
        "CENSUS_SEXB" : {
          "type" : "long"
        },
        "CENSUS_STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREET" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREETB" : {
          "type" : "long"
        },
        "CENSUS_TYPEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_UNITTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_VOLUMEB" : {
          "type" : "long"
        },
        "CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "COUNTY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "LOCATION":{
             "type": "geo_point"
        },
        "LAT" : {
          "type" : "float"
        },
        "LONG" : {
          "type" : "float"
        },
        "MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "METAPHONE_NAMEFIRST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "METAPHONE_NAMELAST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "OBJECTID" : {
          "type" : "long"
        },
        "SIDE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STNAME" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPREDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPRETYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WARD_NUM" : {
          "type" : "long"
        }
      }
    }
  }
'''

# %% [markdown]
# ##### matching - 25k cd matched to 60k census records

# %%
with open('/content/config_1850.json') as json_data_file:
    config = json.load(json_data_file)

es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

config['match_output_filename'] = "/content/test_1850mn_old.csv"
config['unmatch_output_filename'] = "/content/test-u_1850mn_old.csv"

def match_addr():
    df = pd.read_csv(config['cd_filename'])
    count, match,unmatch = 0,0,0
    with open(config['match_output_filename'],'w') as fw, open(config['unmatch_output_filename'],'w') as fw2:
        writer = csv.writer(fw, delimiter="\t",quotechar='"')
        columns = config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""
        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))
        for index, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0:
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}

                else:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} }]}}
            

            if config['edit_distance'] is 0:
                if config['metaphone'] is 1:
                   query =  { "bool" : { "must" : [{ "match": { "CENSUS_FIRST_NAME": data["CD_FIRST_NAME"] } },
                            { "match": { "CENSUS_LAST_NAME": data["CD_LAST_NAME"] } },
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}
            
                else:
                    query = { "bool" : { "must" : [{ "match": { "CENSUS_FIRST_NAME": data["CD_FIRST_NAME"] } },
                            { "match": { "CENSUS_LAST_NAME": data["CD_LAST_NAME"] } },
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]}}]}}

            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
            except exceptions.RequestError:
                print("Exception at row id: ", index)
                continue
            
            if res['hits']['total']['value']!= 0:
                match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
            else:
                fw2.write(str(data['CD_RECORD_ID'])+"\n")
                unmatch+=1
        
    print(count,match,unmatch)

if __name__=='__main__':
    match_addr()

# %% [markdown]
# ### 1850 mn changes:
# 1. name cleaning - remove few identfied special characters. can be more which went unrecognized
#
# 2. durng matching used multiple criteria:
#     * first match on all conditions: first name, last name, ward no and metaphones
#     * for remaining unmatched records match with ward no and metaphones only and remove match condition for first name and last name
#     *  for unmacthed records match after removing ward no only
#     * for remianing unmatched match only on metaphones after remvoving matching conditions for war no, first name and last name

# %% [markdown]
# ##### data ingestion

# %%
import re
es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

logging.basicConfig(filename="/content/bulk_insert.log",
                            filemode='a',
                            format='%(asctime)s %(name)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.WARNING)
logger = logging.getLogger('InsertTime')

def ingest(config):
    df = pd.read_csv(config['census_filename'])
    bulk_data = []
    count = 0 
    for itr, row in df.iterrows():
        count+=1
        row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
        data = row.to_dict() #converts the dataframe row to dictonary with their correct data type
        if 'LOCATION' in data:
          data['LOCATION'] = {"lat":data["LAT"],"lon":data["LONG"]}
        
        if 'ADDNUMFROM' in data and type(data['ADDNUMFROM']) is str:
            data['ADDNUMFROM'] = data['ADDNUMFROM'].replace('`','')

        data[config['census_first_name']] = name_clean(data[config['census_first_name']])
        data[config['census_last_name']] = name_clean(data[config['census_last_name']])
        
        if config['metaphone'] is 1:
          data['METAPHONE_NAMEFIRST'] = [i for i in doublemetaphone(data[config['census_first_name']]) if i]
          data['METAPHONE_NAMELAST'] = [i for i in doublemetaphone(data[config['census_last_name']]) if i]
        
        if id is not False:
          meta = {
              "_index": config['es-index'],
              "_id": data[config['es-id']],
              "_source": data
          }
        else:
          meta = {
              "_index": config['es-index'],
              "_source": data
          }

        bulk_data.append(meta)
        if itr%config['ingest_size'] == 0:
            helpers.bulk(es, bulk_data)
            bulk_data = []
            print("INSERTING NOW", itr)
            
    helpers.bulk(es, bulk_data)
    return count

def name_clean(name):
  name = max(name.split(' '), key=len) # remove middle name if any
  name = re.sub('[^A-Za-z0-9]+', '', name)
   
  return name

if __name__=='__main__':
    if __name__ == '__main__':
      #parser = ArgumentParser()
      #parser.add_argument("-config", help="config file path", default="/content/config_1850.json")

      #args = parser.parse_args()

      #with open(args.config) as json_data_file:
      #  config = json.load(json_data_file)
      with open('/content/config_1850.json') as json_data_file:
         config = json.load(json_data_file)


      st = time.time()
      ingest(config)
      end = time.time()
      logger.warning(config["es-index"] +" "+ str(end-st))
 
#Mapping used
'''
PUT census
{
    "mappings" : {
      "properties" : {
        "ADDNUM" : {
          "type" : "long"
        },
        "ADDNUMFROM" : {
          "type" : "long"
        },
        "ADDNUMTO" : {
          "type" : "long"
        },
        "ADDR_TYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ADDRESSB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_AGEB" : {
          "type" : "long"
        },
        "CENSUS_BUILDING_I" : {
          "type" : "long"
        },
        "CENSUS_CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_ED" : {
          "type" : "long"
        },
        "CENSUS_ENUMDISTB" : {
          "type" : "long"
        },
        "CENSUS_EXTGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_FID" : {
          "type" : "long"
        },
        "CENSUS_MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_MERGEID" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMEFRSTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NAMELASTB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_NEIGHBOR_1" : {
          "type" : "long"
        },
        "CENSUS_NEIGHBOR_2" : {
          "type" : "long"
        },
        "CENSUS_NPERHHB" : {
          "type" : "long"
        },
        "CENSUS_OCCLABELB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_PAGENUMB" : {
          "type" : "long"
        },
        "CENSUS_RACEB" : {
          "type" : "long"
        },
        "CENSUS_RACENAMEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_REELB" : {
          "type" : "long"
        },
        "CENSUS_RELATEB" : {
          "type" : "long"
        },
        "CENSUS_RELATE_STR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_SEGGROUP_I" : {
          "type" : "long"
        },
        "CENSUS_SEGMENT_ID" : {
          "type" : "long"
        },
        "CENSUS_SERIAL" : {
          "type" : "long"
        },
        "CENSUS_SERIALB" : {
          "type" : "long"
        },
        "CENSUS_SEXB" : {
          "type" : "long"
        },
        "CENSUS_STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREET" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_STREETB" : {
          "type" : "long"
        },
        "CENSUS_TYPEB" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_UNITTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "CENSUS_VOLUMEB" : {
          "type" : "long"
        },
        "CITY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "COUNTY" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "LOCATION":{
             "type": "geo_point"
        },
        "LAT" : {
          "type" : "float"
        },
        "LONG" : {
          "type" : "float"
        },
        "MATCH_ADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "METAPHONE_NAMEFIRST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "METAPHONE_NAMELAST": {
          "type": "text",
          "fields": {
            "keyword": {
                "type": "keyword",
                "ignore_above": 256
            }
          }
        },
        "OBJECTID" : {
          "type" : "long"
        },
        "SIDE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STADDR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STATE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STNAME" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPREDIR" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STPRETYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "STTYPE" : {
          "type" : "text",
          "fields" : {
            "keyword" : {
              "type" : "keyword",
              "ignore_above" : 256
            }
          }
        },
        "WARD_NUM" : {
          "type" : "long"
        }
      }
    }
  }
'''
# Out:
# INSERTING NOW 0
# INSERTING NOW 5000
# INSERTING NOW 10000
# INSERTING NOW 15000
# INSERTING NOW 20000
# INSERTING NOW 25000
# INSERTING NOW 30000
# INSERTING NOW 35000
# INSERTING NOW 40000
# INSERTING NOW 45000
# INSERTING NOW 50000
# INSERTING NOW 55000
# INSERTING NOW 60000
# INSERTING NOW 65000
# INSERTING NOW 70000
# INSERTING NOW 75000
# INSERTING NOW 80000
# INSERTING NOW 85000
# INSERTING NOW 90000
# INSERTING NOW 95000
# INSERTING NOW 100000
# INSERTING NOW 105000
# INSERTING NOW 110000
# INSERTING NOW 115000
# INSERTING NOW 120000
# INSERTING NOW 125000
# INSERTING NOW 130000
# INSERTING NOW 135000
# INSERTING NOW 140000
# INSERTING NOW 145000
# INSERTING NOW 150000
# INSERTING NOW 155000
# INSERTING NOW 160000
# INSERTING NOW 165000
# INSERTING NOW 170000
# INSERTING NOW 175000
# INSERTING NOW 180000
# INSERTING NOW 185000
# INSERTING NOW 190000
# INSERTING NOW 195000
# INSERTING NOW 200000
# INSERTING NOW 205000
# INSERTING NOW 210000
# INSERTING NOW 215000
# INSERTING NOW 220000
# INSERTING NOW 225000
# INSERTING NOW 230000
# INSERTING NOW 235000
# INSERTING NOW 240000
# INSERTING NOW 245000
# INSERTING NOW 250000
# INSERTING NOW 255000
# INSERTING NOW 260000
# INSERTING NOW 265000
# INSERTING NOW 270000
# INSERTING NOW 275000
# INSERTING NOW 280000
# INSERTING NOW 285000
# INSERTING NOW 290000
# INSERTING NOW 295000
# INSERTING NOW 300000
# INSERTING NOW 305000
# INSERTING NOW 310000
# INSERTING NOW 315000
# INSERTING NOW 320000
# INSERTING NOW 325000
# INSERTING NOW 330000
# INSERTING NOW 335000
# INSERTING NOW 340000
# INSERTING NOW 345000
# INSERTING NOW 350000
# INSERTING NOW 355000
# INSERTING NOW 360000
# INSERTING NOW 365000
# INSERTING NOW 370000
# INSERTING NOW 375000
# INSERTING NOW 380000
# INSERTING NOW 385000
# INSERTING NOW 390000
# INSERTING NOW 395000
# INSERTING NOW 400000
# INSERTING NOW 405000
# INSERTING NOW 410000
# INSERTING NOW 415000
# INSERTING NOW 420000
# INSERTING NOW 425000
# INSERTING NOW 430000
# INSERTING NOW 435000
# INSERTING NOW 440000
# INSERTING NOW 445000
# INSERTING NOW 450000
# INSERTING NOW 455000
# INSERTING NOW 460000
# INSERTING NOW 465000
# INSERTING NOW 470000
# INSERTING NOW 475000
# INSERTING NOW 480000
# INSERTING NOW 485000
# INSERTING NOW 490000
# INSERTING NOW 495000
# INSERTING NOW 500000
# INSERTING NOW 505000
# INSERTING NOW 510000
# INSERTING NOW 515000
# '\nPUT census\n{\n    "mappings" : {\n      "properties" : {\n        "ADDNUM" : {\n          "type" : "long"\n        },\n        "ADDNUMFROM" : {\n          "type" : "long"\n        },\n        "ADDNUMTO" : {\n          "type" : "long"\n        },\n        "ADDR_TYPE" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_ADDRESSB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_AGEB" : {\n          "type" : "long"\n        },\n        "CENSUS_BUILDING_I" : {\n          "type" : "long"\n        },\n        "CENSUS_CITY" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_ED" : {\n          "type" : "long"\n        },\n        "CENSUS_ENUMDISTB" : {\n          "type" : "long"\n        },\n        "CENSUS_EXTGROUP_I" : {\n          "type" : "long"\n        },\n        "CENSUS_FID" : {\n          "type" : "long"\n        },\n        "CENSUS_MATCH_ADDR" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_MERGEID" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_NAMEFRSTB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_NAMELASTB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_NEIGHBOR_1" : {\n          "type" : "long"\n        },\n        "CENSUS_NEIGHBOR_2" : {\n          "type" : "long"\n        },\n        "CENSUS_NPERHHB" : {\n          "type" : "long"\n        },\n        "CENSUS_OCCLABELB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_PAGENUMB" : {\n          "type" : "long"\n        },\n        "CENSUS_RACEB" : {\n          "type" : "long"\n        },\n        "CENSUS_RACENAMEB" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_REELB" : {\n          "type" : "long"\n        },\n        "CENSUS_RELATEB" : {\n          "type" : "long"\n        },\n        "CENSUS_RELATE_STR" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_SEGGROUP_I" : {\n          "type" : "long"\n        },\n        "CENSUS_SEGMENT_ID" : {\n          "type" : "long"\n        },\n        "CENSUS_SERIAL" : {\n          "type" : "long"\n        },\n        "CENSUS_SERIALB" : {\n          "type" : "long"\n        },\n        "CENSUS_SEXB" : {\n          "type" : "long"\n        },\n        "CENSUS_STATE" : {\n          "type" : "text",\n          "fields" : {\n            "keyword" : {\n              "type" : "keyword",\n              "ignore_above" : 256\n            }\n          }\n        },\n        "CENSUS_STREET" : {\n          "type" : "text",\n          "fields" : {\n ...

# %% [markdown]
# ##### matching

# %%
with open('/content/config_1850.json') as json_data_file:
    config = json.load(json_data_file)

es = Elasticsearch(hosts=["http://localhost:9200"], timeout=60, retry_on_timeout=True)

config['match_output1_filename'] = "/content/test_match_allcond.csv"
config['match_output2_filename'] = "/content/test_match_noward.csv"
config['match_output3_filename'] = "/content/test_match_nonamematch.csv"
config['match_output4_filename'] = "/content/test_match_onlymetaphone.csv"
config['identifier_col'] = ['identifier_col']

def match_addr():
    df = pd.read_csv(config['cd_filename'])
    count, match,unmatch = 0,0,0
    with open(config['match_output_filename'],'w') as fw, open(config['match_output1_filename'],'w') as fw1, open(config['match_output2_filename'],'w') as fw2, open(config['match_output3_filename'],'w') as fw3, open(config['match_output4_filename'],'w') as fw4, open(config['unmatch_output_filename'],'w') as fw5:
        writer = csv.writer(fw, delimiter="\t",quotechar='"')
        columns = config['identifier_col'] + config["output_census_cols"] + config["output_city_directory_cols"]
        rows=""
        for cols in columns:
            rows = rows + cols + "\t"
        
        writer.writerow(rows.rstrip("\t").split("\t"))


        for index, row in df.iterrows():
            row = row.replace(np.nan,'',regex=True) #covnert nan to empty string
            data = row.to_dict()
            
            data["CD_FIRST_NAME"] = name_clean(data["CD_FIRST_NAME"])
            data["CD_LAST_NAME"] = name_clean(data["CD_LAST_NAME"])
            
            first_name_metaphone = [i for i in doublemetaphone(data["CD_FIRST_NAME"]) if i]
            last_name_metaphone = [i for i in doublemetaphone(data["CD_LAST_NAME"]) if i]

            if config['edit_distance'] !=0:
                if config['metaphone'] is 1:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}

                    query2 = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                            #{ "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}

                    query3 = { "bool" : { "must" : [{ "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}


                    query4 = { "bool" : { "must" : [
                            {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}},
                            {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}
                else:
                    query = { "bool" : { "must" : [{ "fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } } },
                            {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
                            { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} }]}}
            


            #if (data["CD_FIRST_NAME"] == ''):
            #        query = { "bool" : { "must" : [
            #                {"fuzzy": { "CENSUS_LAST_NAME": { "value": data["CD_LAST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
            #                { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
            #                {"terms": {"METAPHONE_NAMELAST.keyword": last_name_metaphone}}]}}
            
            #if (data["CD_LAST_NAME"] == ''):
            #        query = { "bool" : { "must" : [
            #                {"fuzzy": { "CENSUS_FIRST_NAME": { "value": data["CD_FIRST_NAME"], "fuzziness": config["edit_distance"], "max_expansions": 50, "prefix_length": 0, "transpositions": True, "rewrite": "constant_score" } }},
            #                { "match" : { "CENSUS_WARD_NUM": data["CD_WARD_NUM"]} },
            #                {"terms": {"METAPHONE_NAMEFIRST.keyword": first_name_metaphone}}]}}
            
            
            try:
                res = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query})
                res3 = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query3})
                res2 = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query2})
                res4 = es.search(index=config["es-index"], body={ "from": 0, "size": 10000, "query":query4})
                

            except exceptions.RequestError:
                print("Exception at row id: ", index)
                continue
            
            if res['hits']['total']['value']!= 0:
                match+=1
                for i in res['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["identifier_col"]:
                        content = content + 'allconditions' + "\t"
                    
                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
                    fw1.write(str(data['CD_RECORD_ID'])+"\n")

            
            elif res3['hits']['total']['value']!= 0:
                match+=1
                for i in res3['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["identifier_col"]:
                        content = content + 'nonamematch' + "\t"

                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
                    fw3.write(str(data['CD_RECORD_ID'])+"\n")

            elif res2['hits']['total']['value']!= 0:
                match+=1
                for i in res2['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["identifier_col"]:
                        content = content + 'noward' + "\t"

                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
                    fw2.write(str(data['CD_RECORD_ID'])+"\n")


            elif res4['hits']['total']['value']!= 0:
                match+=1
                for i in res4['hits']['hits']:
                    i = i['_source']
                    content = ""
                    for j in config["identifier_col"]:
                        content = content + 'onlymetaphone' + "\t"

                    for j in config["output_census_cols"]:
                        content = content + str(i[j]) + "\t"

                    for j in config["output_city_directory_cols"]:
                        content = content + str(data[j]) + "\t"

                    writer.writerow(content.rstrip("\t").split("\t"))
                    fw4.write(str(data['CD_RECORD_ID'])+"\n")

            else:
                fw5.write(str(data['CD_RECORD_ID'])+"\n")
                unmatch+=1
        
    print(count,match,unmatch)

def name_clean(name):
  name = max(name.split(' '), key=len) # remove middle name if any
  name = re.sub('[^A-Za-z0-9]+', '', name)
   
  return name
  

if __name__=='__main__':
    match_addr()
# Out:
# 0 42961 14786

# %% [markdown]
# ### Remove duplicates, check no of rows in each condition and resave the files

# %%
# find the count of matches in each config file
import pandas as pd
test_match_allcond = pd.read_csv("/content/test_match_allcond.csv", error_bad_lines=False, header = None) # match with all conditions
test_match_noward = pd.read_csv("/content/test_match_noward.csv", error_bad_lines=False, header = None) # match after removing ward no
test_match_nonamematch = pd.read_csv("/content/test_match_nonamematch.csv", error_bad_lines=False, header = None) # match with ward no and metaphones
test_match_onlymetaphone = pd.read_csv("/content/test_match_onlymetaphone.csv", error_bad_lines=False, header = None) # match with only metaphones
test_nomatch = pd.read_csv("/content/test-u.csv", error_bad_lines=False, header = None) # non matched cd records
test_match = pd.read_csv("/content/test.csv", error_bad_lines=False, delimiter='\t') # matched information

# remove duplicates
test_match_allcond.drop_duplicates(inplace=True)
test_match_noward.drop_duplicates(inplace=True)
test_match_nonamematch.drop_duplicates(inplace=True)
test_match_onlymetaphone.drop_duplicates(inplace=True)
test_nomatch.drop_duplicates(inplace=True)
test_match.drop_duplicates(inplace=True)

# %%
print(len(test_match_allcond))
print(len(test_match_noward)) # no ward
print(len(test_match_nonamematch)) # uses ward no and metaphones
print(len(test_match_onlymetaphone)) # no ward, first and last names
print(len(test_nomatch))
print(len(test_match))
# Out:
# 25492
# 6402
# 7152
# 3833
# 14737
# 135302

# %%
# save all the files again

test_match_allcond.to_csv("/content/test_match_allcond.csv", index= False)
test_match_noward.to_csv("/content/test_match_noward.csv", index= False)
test_match_nonamematch.to_csv("/content/test_match_nonamematch.csv", index= False)
test_match_onlymetaphone.to_csv("/content/test_match_onlymetaphone.csv", index= False)
test_nomatch.to_csv("/content/test-u.csv", index= False)
test_match.to_csv("/content/test_matched.csv", index= False)
