# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import re
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# census_1880 = pd.read_csv("data/census_1880_mn_v04.csv")
census_1850 = pd.read_csv("data/census_1850_indexUpdate.csv")
census_1880 = pd.read_csv("data/census_1880_mn_v04.csv")#select columns to use
# Out:
# /Users/tabithasugumar/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#select columns to use
print(census_1880.columns)
print(census_1850.columns)
# Out:
# Index(['OBJECTID.x', 'CENSUS_MERGEID', 'CENSUS_SERIALB', 'CENSUS_SERIAL',
#        'CENSUS_PERNUM', 'CENSUS_RECIDUS', 'CENSUS_REEL', 'CENSUS_VOLUME',
#        'CENSUS_PAGENUM', 'CENSUS_NAMEFRSTB', 'CENSUS_NAMELASTB',
#        'CENSUS_RELATE', 'CENSUS_RELATE_STR', 'CENSUS_AGE', 'CENSUS_SEXB',
#        'CENSUS_RACENAMEB', 'CENSUS_RACEB', 'CENSUS_NPERHHB',
#        'CENSUS_OCCLABELB', 'CENSUS_SEIUSBN', 'CENSUS_MATCH_ADDR',
#        'CENSUS_HOUSE_NUMB', 'CENSUS_STREETB', 'CENSUS_TYPEB',
#        'CENSUS_SEGMENT_ID', 'CENSUS_BUILDING_I', 'CENSUS_NEIGHBOR_1',
#        'CENSUS_NEIGHBOR_2', 'CENSUS_SEGGROUP_I', 'CENSUS_EXTGROUP_I',
#        'CENSUS_CITY', 'CENSUS_COUNTYUS', 'CENSUS_X', 'CENSUS_Y',
#        'CENSUS_ADDRESS', 'CENSUS_ENUMDIST', 'CENSUS_CITYNAME',
#        'CENSUS_STATENAME', 'CENSUS_UNITTYPE', 'MERGE_SRC', 'WARD_NUM',
#        'CENSUS_AD'],
#       dtype='object')
# Index(['CENSUS_SERIALP', 'CENSUS_AGE', 'CENSUS_SEX', 'CENSUS_MARST',
#        'CENSUS_RACE', 'CENSUS_LABFORCE', 'CENSUS_IMPREL', 'CENSUS_OCCSTR',
#        'CENSUS_NAMELAST', 'CENSUS_NAMEFRST', 'CENSUS_SEQ_NUM', 'CENSUS_HH_NUM',
#        'CENSUS_IPUMS_UID', 'CENSUS_CITY', 'CENSUS_PAGENO_HOUSEHOLD',
#        'CENSUS_WARD_NUM', 'CENSUS_REEL_HOUSEHOLD', 'CENSUS_PLACE',
#        'CENSUS_DWELLING_NUM', 'CENSUS_DWELLING_SEQ', 'CENSUS_DWELLING_SIZE',
#        'CENSUS_GEOG', 'CENSUS_LINE', 'CENSUS_INDEX'],
#       dtype='object')

# %% [markdown]
# #### Let's investigate what the feature options are, and their distributions

# %%
display(census_1880.head())
display(census_1850.head())
# Out:
#    OBJECTID.x             CENSUS_MERGEID  CENSUS_SERIALB  CENSUS_SERIAL  \
# 0           1     46101106EDITH K.SANGER         6347938        6198399
# 1           2  461012776EMMAVAN BROSELIN         6347938        6198399
# 2           3      461012776LIZZIEMALONE         6347938        6198399
# 3           4   461012806FANNIE K.SANGER         6347938        6198399
# 4           5    461012876MITCHILL A.LEE         6347938        6198399
#
#    CENSUS_PERNUM          CENSUS_RECIDUS  CENSUS_REEL  CENSUS_VOLUME  \
# 0              3  01254866-1-0001-0003-$          866              1
# 1              6  01254866-1-0001-0006-$          866              1
# 2              4  01254866-1-0001-0004-$          866              1
# 3              2  01254866-1-0001-0002-$          866              1
# 4              5  01254866-1-0001-0005-$          866              1
#
#    CENSUS_PAGENUM CENSUS_NAMEFRSTB  ...   CENSUS_X   CENSUS_Y  \
# 0               1         EDITH K.  ... -74.016751  40.690711
# 1               1             EMMA  ... -74.016751  40.690711
# 2               1           LIZZIE  ... -74.016751  40.690711
# 3               1        FANNIE K.  ... -74.016751  40.690711
# 4               1      MITCHILL A.  ... -74.016751  40.690711
#
#         CENSUS_ADDRESS  CENSUS_ENUMDIST  CENSUS_CITYNAME CENSUS_STATENAME  \
# 0  36 GOVERNORS ISLAND                1    NYC-Manhattan               NY
# 1  36 GOVERNORS ISLAND                1    NYC-Manhattan               NY
# 2  36 GOVERNORS ISLAND                1    NYC-Manhattan               NY
# 3  36 GOVERNORS ISLAND                1    NYC-Manhattan               NY
# 4  36 GOVERNORS ISLAND                1    NYC-Manhattan               NY
#
#    CENSUS_UNITTYPE          MERGE_SRC WARD_NUM  CENSUS_AD
# 0      single unit  NYC-ManhattanCE1a      1.0        1.0
# 1      single unit  NYC-ManhattanCE1a      1.0        1.0
# 2      single unit  NYC-ManhattanCE1a      1.0        1.0
# 3      single unit  NYC-ManhattanCE1a      1.0        1.0
# 4      single unit  NYC-ManhattanCE1a      1.0        1.0
#
# [5 rows x 42 columns]
#    CENSUS_SERIALP  CENSUS_AGE  CENSUS_SEX  CENSUS_MARST  CENSUS_RACE  \
# 0         2044262          49           1             6          120
# 1         2044263          36           2             6          120
# 2         2044264          12           2             6          120
# 3         2044265          40           1             6          120
# 4         2044266          28           2             6          120
#
#    CENSUS_LABFORCE  CENSUS_IMPREL  CENSUS_OCCSTR CENSUS_NAMELAST  \
# 0                2              1     INN KEEPER           FLINT
# 1                0              1            NaN           FLINT
# 2                0              1            NaN           FLINT
# 3                2              1  COMB MERCHANT          OATMAN
# 4                0              1            NaN          OATMAN
#
#   CENSUS_NAMEFRST  ...  CENSUS_PAGENO_HOUSEHOLD  CENSUS_WARD_NUM  \
# 0          JOHN M  ...                       70                1
# 1          MARY A  ...                       70                1
# 2          MARY D  ...                       70                1
# 3         JAMES C  ...                       70                1
# 4      CAROLINE E  ...                       70                1
#
#   CENSUS_REEL_HOUSEHOLD  CENSUS_PLACE  CENSUS_DWELLING_NUM  \
# 0                   534     MANHATTAN                  1.0
# 1                   534     MANHATTAN                  1.0
# 2                   534     MANHATTAN                  1.0
# 3                   534     MANHATTAN                  1.0
# 4                   534     MANHATTAN                  1.0
#
#    CENSUS_DWELLING_SEQ  CENSUS_DWELLING_SIZE  \
# 0                  1.0                    84
# 1                  1.0                    84
# 2                  1.0                    84
# 3                  1.0                    84
# 4                  1.0                    84
#
#                         CENSUS_GEOG  CENSUS_LINE  CENSUS_INDEX
# 0  NEW YORK WARD 1 EASTERN DIVISION           10             1
# 1  NEW YORK WARD 1 EASTERN DIVISION           10             2
# 2  NEW YORK WARD 1 EASTERN DIVISION           10             3
# 3  NEW YORK WARD 1 EASTERN DIVISION           10             4
# 4  NEW YORK WARD 1 EASTERN DIVISION           10             5
#
# [5 rows x 24 columns]

# %%
census_1880_model = census_1880["CENSUS_AGE", "CENSUS_PAGENUM", "WARD_NUM", "CENSUS_RACEB", ""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('CENSUS_AGE', 'CENSUS_PAGENUM', 'WARD_NUM', 'CENSUS_RACEB', '')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-b1c54c2ecf12> in <module>
# ----> 1 census_1880_model = census_1880["CENSUS_AGE", "CENSUS_PAGENUM", "WARD_NUM", "CENSUS_RACEB", ""]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('CENSUS_AGE', 'CENSUS_PAGENUM', 'WARD_NUM', 'CENSUS_RACEB', '')

# %%
wards = [3,9,10,18,21,22]
census_1880_train = census_1880[~census_1880["CENSUS_WARD_NUM"].isin(wards)]
census_1880_test
